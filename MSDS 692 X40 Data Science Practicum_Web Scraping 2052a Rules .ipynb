# %% [markdown]
# ## 2052a Rules Web Scraping
#
# ### Project Description
# FR 2052a reporting is a requirement for large complex banking institutions to communicate the strength of their liquidity coverage to the Federal Reserve Bank, in an effort to not disrupt the global banking system.  Large banking institutions such as the bank I currently am employed at are required to submit this report either monthly or daily based on the complexity of a banks operations; this relates to the whole concept of Globally Systematically Important Banks or GSIBs.
#
# Currently the institution that I work at uses a PFD and reads through the 2052a rules to correctly map portions of our balance sheet to the liquidity coverage ratio (LCR) and more broadly to the 2052a submission which covers a banking institutions entire balance sheet.  This leaves a lot of room for human error; and if rules change for an example if an update is made and the banking institution is relying on mapping based on an old set of rules.  Errors of this nature can result in findings from the FRB including costly and time-consuming remediation plans.
#
# This project will point to the most recent set of rules from the Federal Reserve bank.  The goal is to scrape the tables for all of the 2052a/LCR rules; and eventually create an interface with logic around rules for correct assignment and classification is assigned and mapped to banking specifically my banking institutions balance sheet.
#
# For this project we will us Python's tabula, we will first start by pip installing tabula-py and then importing it into our notebook

# %%
#!pip install tabula-py
import tabula
import pandas as pd
import numpy as np

# %%
#point to FRB 2052a Website for the file locaton: 
File = "https://www.federalreserve.gov/reportforms/forms/FR_2052a20200630_f.pdf"

# %% [markdown]
# Now we can test reading the PDF, calling all pages to incorporate the whole document to be read by tabula

# %%
tables = tabula.read_pdf(File, pages = "all", multiple_tables = True,  java_options= "-Dfile.encoding=UTF8")
# Out:
# Got stderr: Sep 20, 2020 3:32:50 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+3409 (3409) in font GKPCDN+Cambria
# Sep 20, 2020 3:32:50 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+3404 (3404) in font CNMILO+Cambria
# Sep 20, 2020 3:32:50 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+4666 (4666) in font CNMILO+Cambria
# Sep 20, 2020 3:32:50 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+3398 (3398) in font CNMILO+Cambria
# Sep 20, 2020 3:32:50 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+4667 (4667) in font CNMILO+Cambria
# Sep 20, 2020 3:32:50 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+3397 (3397) in font CNMILO+Cambria
# Sep 20, 2020 3:32:50 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+4670 (4670) in font CNMILO+Cambria
# Sep 20, 2020 3:32:50 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+4671 (4671) in font CNMILO+Cambria
# Sep 20, 2020 3:32:51 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+3533 (3533) in font CNMILO+Cambria
# Sep 20, 2020 3:32:51 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+3040 (3040) in font CNMILO+Cambria
# Sep 20, 2020 3:32:51 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+3041 (3041) in font CNMILO+Cambria
# Sep 20, 2020 3:32:51 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+2880 (2880) in font CNMILO+Cambria
# Sep 20, 2020 3:32:51 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+2869 (2869) in font CNMILO+Cambria
# Sep 20, 2020 3:32:51 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+4668 (4668) in font CNMILO+Cambria
# Sep 20, 2020 3:32:51 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+4669 (4669) in font CNMILO+Cambria
# Sep 20, 2020 3:32:51 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+2871 (2871) in font CNMILO+Cambria
# Sep 20, 2020 3:32:51 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+2868 (2868) in font CNMILO+Cambria

# %%
tables
# Out:
# [   Unnamed: 0                                         Unnamed: 1  \
#  0         NaN                               Reporter Description
#  1         NaN                                                NaN
#  2                  U.S. firms that are identified as (i) Global
#  3         NaN     systemically important bank holding companies;
#  4         NaN   (ii) Category II banking organizations; or (iii)
#  5         NaN        Category III banking organizations and have
#  6         NaN      average weighted short‐term wholesale funding
#  7         NaN                            of $75 billion or more.
#  8             FBOs that are identified as (i) Category II fo...
#  9         NaN  banking organizations; or (ii) Category III fo...
#  10        NaN        banking organizations with average weighted
#  11        NaN     short‐term wholesale funding of $75 billion or
#  12        NaN                                              more.
#  13                U.S. firms identified as Category III banking
#  14        NaN     organizations and have average weighted short‐
#  15        NaN   term wholesale funding of less than $75 billion.
#  16              FBOs identified as Category III foreign banking
#  17        NaN                                                NaN
#  18        NaN     organizations with average weighted short‐term
#  19        NaN        wholesale funding of less than $75 billion.
#  20                U.S. firms that are identified as Category IV
#  21        NaN                             banking organizations.
#  22               FBOs identified as Category IV foreign banking
#  23        NaN                                     organizations.
#
#             Unnamed: 2   Timing of
#  0          Frequency3         NaN
#  1                 NaN  Submission
#  2                 NaN         NaN
#  3                 NaN         NaN
#  4                 NaN         NaN
#  5                 NaN         NaN
#  6                 NaN         NaN
#  7                 NaN         NaN
#  8   Each Business Day         T+2
#  9                 NaN         NaN
#  10                NaN         NaN
#  11                NaN         NaN
#  12                NaN         NaN
#  13                NaN         NaN
#  14                NaN         NaN
#  15                NaN         NaN
#  16                NaN         NaN
#  17                  4         NaN
#  18            Monthly         T+2
#  19                NaN         NaN
#  20                NaN         NaN
#  21                NaN         NaN
#  22                NaN         NaN
#  23           Monthly5        T+10  ,
#      Unnamed: 0 Reporting          Unnamed: 1 Unnamed: 2       Unnamed: 3  \
#  0  O.D fields:       NaN  Currency Converted        PID          Product
#  1          NaN    Entity                 NaN        NaN              NaN
#  2    Sample 1:      BANK              USD No          4      Operational
#  3    Sample 2:      BANK              USD No          5  Non‐operational
#  4    Sample 3:      BANK              USD No          5  Non‐operational
#
#    Unnamed: 4               Unnamed: 5 Maturity Maturity Collateral Collateral  \
#  0        SID              Sub‐Product                          NaN        NaN
#  1        NaN                      NaN          Amount Bucket Class      Value
#  2          3  Non‐financial corporate                   1,000 Open        NaN
#  3          3  Non‐financial corporate                     500 Open        NaN
#  4          3  Non‐financial corporate                    750 Day 5        NaN
#
#    Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9      Internal
#  0    Insured    Trigger    Rehyp'd   Internal           NaN
#  1        NaN        NaN        NaN        NaN  Counterparty
#  2       FDIC          N        NaN          N           NaN
#  3  Uninsured          N        NaN          N           NaN
#  4  Uninsured          N        NaN          N           NaN  ,
#           Inflows        Outflows    Supplementa
#  0         Assets        Deposits  Informational
#  1            NaN             NaN          Items
#  2      Unsecured       Wholesale            NaN
#  3            NaN             NaN        Foreign
#  4        Secured         Secured       exchange
#  5  Other inflows  Other outflows       Comments,
#      Unnamed: 0 Unnamed: 1          Unnamed: 2 Unnamed: 3  \
#  0          NaN  Reporting                 NaN        NaN
#  1  O.W fields:        NaN  Currency Converted        PID
#  2          NaN     Entity                 NaN        NaN
#  3    Sample 1:     PARENT              USD No         12
#  4    Sample 2:     PARENT              GBP No         12
#  5    Sample 3:     PARENT              GBP No         12
#
#                        Unnamed: 4  \
#  0                            NaN
#  1                        Product
#  2                            NaN
#  3  LTD ‐ Non‐Structured >4Y_<=5Y
#  4           LTD ‐ Non‐Structured
#  5  LTD ‐ Non‐Structured >1Y_<=2Y
#
#                                            Unnamed: 5 Unnamed: 6  \
#  0  Maturity Maturity Collateral Collateral Fwd St...        NaN
#  1                                                NaN   Internal
#  2            Bucket Amount Class Value Amount Bucket        NaN
#  3                                              1,500          N
#  4                                          >5Y 2,000          N
#  5                                                250          N
#
#                 Unnamed: 7
#  0          Internal Prime
#  1                     NaN
#  2  Counterparty Brokerage
#  3                       N
#  4                       N
#  5                       N  ,
#            Unnamed: 0 Unnamed: 1  \
#  0             Prefix          .
#  1       I\r(Inflows)          .
#  2      O\r(Outflows)          .
#  3  S\r(Supplemental)          .
#
#                                            Unnamed: 2 Unnamed: 3 Product
#  0                                              Table          .       #
#  1  A (Assets)\rU (Unsecured)\rS (Secured)\rO (Other)          .       #
#  2  D (Deposits)\rW (Wholesale)\rS (Secured)\rO (O...          .       #
#  3     I (Informational Items)\rFX (Foreign Exchange)          .       #  ,
#      Unnamed: 0 Reporting              Unnamed: 1 Unnamed: 2 Unnamed: 3  \
#  0  I.A fields:       NaN  Currency Converted PID    Product        SID
#  1          NaN    Entity                     NaN        NaN        NaN
#  2      Sample:      BANK                USD No 2   Capacity          9
#
#        Sub‐ Maturity Market Lendable Fwd Start Fwd Start Collateral Treasury
#  0      NaN      NaN    NaN                                     NaN      NaN
#  1  Product   Bucket  Value               Value Amount Bucket Class  Control
#  2     FHLB     Open    150                                 100 L‐3        Y  ,
#                          Outflow adjustment percentage Unnamed: 0
#  0   Global systemically important BHC or GSIB depo...        100
#  1                                                 NaN    percent
#  2             Category II Board‐regulated institution        100
#  3                                                 NaN    percent
#  4   Category III Board‐regulated institution with ...        100
#  5   term wholesale funding and any Category III Bo...    percent
#  6   consolidated subsidiary of such a Category III...        NaN
#  7   Category III Board‐regulated institution with ...         85
#  8   term wholesale funding and any Category III Bo...    percent
#  9   consolidated subsidiary of such a Category III...        NaN
#  10  Category IV Board‐regulated institution with $...         70
#  11                             term wholesale funding    percent,
#                Unnamed: 0 (1) High‐Quality Liquid Assets (Subpart C, §.20‐.22)
#  0                  Field                                              Value
#  1       Reporting Entity                                           LCR Firm
#  2               Currency                                                  *
#  3              Converted                                                  #
#  4                    PID                                    I.A.1, 2, and 3
#  5                Product                                        Matches PID
#  6                    SID                                Matches Sub‐Product
#  7            Sub‐Product                                     Not Other Cash
#  8           Market Value                                                  *
#  9         Lendable Value                                                  #
#  10       Maturity Bucket                        Open for I.A.3, # otherwise
#  11  Forward Start Amount                                               NULL
#  12  Forward Start Bucket                                               NULL
#  13      Collateral Class                      HQLA (except A‐0‐Q for I.A.2)
#  14      Treasury Control                                                  Y  ,
#                     Unnamed: 0  \
#  0                       Field
#  1            Reporting Entity
#  2                    Currency
#  3                   Converted
#  4                         PID
#  5                     Product
#  6                         SID
#  7                 Sub‐Product
#  8             Maturity Amount
#  9             Maturity Bucket
#  10  Effective Maturity Bucket
#  11       Forward Start Amount
#  12       Forward Start Bucket
#  13           Collateral Class
#  14           Collateral Value
#  15               Unencumbered
#  16           Treasury Control
#  17                   Internal
#  18      Internal Counterparty
#  19            Prime Brokerage
#  20                 Settlement
#  21                        CID
#  22               Counterparty
#
#     (2) Rehypothecatable Collateral (Subpart C, §.20‐.22)
#  0                                               Value
#  1                                            LCR Firm
#  2                                                   *
#  3                                                   #
#  4                            I.S.1, 2, 3, 4, 5, and 6
#  5                                         Matches PID
#  6                                                   #
#  7                                                   #
#  8                                                   #
#  9                                                   #
#  10                                               NULL
#  11                                               NULL
#  12                                               NULL
#  13                                HQLA (except A‐0‐Q)
#  14                                                  *
#  15                                                  Y
#  16                                                  Y
#  17                                                  #
#  18                                                  #
#  19                                                  #
#  20                                                  #
#  21                                                  #
#  22                                                  #     ,
#      Unnamed: 0 (3) Rehypothecatable Collateral (Subpart C, §.20‐.22)  \
#  0          NaN                                                NaN
#  1          NaN                                              Field
#  2          NaN                                   Reporting Entity
#  3          NaN                                           Currency
#  4          NaN                                          Converted
#  5          NaN                                                PID
#  6          NaN                                            Product
#  7          NaN                                                SID
#  8          NaN                                        Sub‐Product
#  9          NaN                                               SID2
#  10         NaN                                       Sub‐Product2
#  11         NaN                                       Market Value
#  12         NaN                                   Collateral Class
#  13         NaN                                           Internal
#  14         NaN                              Internal Counterparty
#  15         NaN                                    Prime Brokerage
#
#      Unnamed: 1                         Unnamed: 2  Unnamed: 3
#  0          NaN                                NaN         NaN
#  1          NaN                              Value         NaN
#  2          NaN                           LCR Firm         NaN
#  3          NaN                                  *         NaN
#  4          NaN                                  #         NaN
#  5          NaN                        S.I.3 and 6         NaN
#  6          NaN                        Matches PID         NaN
#  7          NaN                Matches Sub‐Product         NaN
#  8          NaN  Unencumbered and Treasury Control         NaN
#  9          NaN                                  #         NaN
#  10         NaN                                  #         NaN
#  11         NaN                                  *         NaN
#  12         NaN                               HQLA         NaN
#  13         NaN                                  #         NaN
#  14         NaN                                  #         NaN
#  15         NaN                                  #         NaN  ,
#      Unnamed: 0                                Unnamed: 1  Unnamed: 2  \
#  0          NaN  (4) Excluded Sub HQLA (§.22(b)(3)and(4))         NaN
#  1          NaN                                     Field         NaN
#  2          NaN                          Reporting Entity         NaN
#  3          NaN                                  Currency         NaN
#  4          NaN                                 Converted         NaN
#  5          NaN                                       PID         NaN
#  6          NaN                                   Product         NaN
#  7          NaN                                       SID         NaN
#  8          NaN                               Sub‐Product         NaN
#  9          NaN                                      SID2         NaN
#  10         NaN                              Sub‐Product2         NaN
#  11         NaN                              Market Value         NaN
#  12         NaN                          Collateral Class         NaN
#  13         NaN                                  Internal         NaN
#  14         NaN                     Internal Counterparty         NaN
#  15         NaN                           Prime Brokerage         NaN
#
#       Unnamed: 3  Unnamed: 4
#  0           NaN         NaN
#  1         Value         NaN
#  2      LCR Firm         NaN
#  3             *         NaN
#  4             #         NaN
#  5        S.I.19         NaN
#  6   Matches PID         NaN
#  7             #         NaN
#  8             #         NaN
#  9             #         NaN
#  10            #         NaN
#  11            *         NaN
#  12         HQLA         NaN
#  13            #         NaN
#  14            #         NaN
#  15            #         NaN  ,
#     Unnamed: 0                                         Unnamed: 1  Unnamed: 2  \
#  0         NaN  (5) Early Hedge Termination Outflows (§.22(a)(3))         NaN
#  1         NaN                                                NaN         NaN
#  2         NaN                                              Field         NaN
#  3         NaN                                   Reporting Entity         NaN
#  4         NaN                                           Currency         NaN
#  5         NaN                                          Converted         NaN
#  6         NaN                                                PID         NaN
#
#    Unnamed: 3  Unnamed: 4
#  0        NaN         NaN
#  1        NaN         NaN
#  2      Value         NaN
#  3   LCR Firm         NaN
#  4          *         NaN
#  5          #         NaN
#  6     S.I.21         NaN  ,
#     Unnamed: 0                Product  Unnamed: 1 Matches PID  Unnamed: 2
#  0         NaN                    SID         NaN           #         NaN
#  1         NaN            Sub‐Product         NaN           #         NaN
#  2         NaN                   SID2         NaN           #         NaN
#  3         NaN           Sub‐Product2         NaN           #         NaN
#  4         NaN           Market Value         NaN           *         NaN
#  5         NaN       Collateral Class         NaN        HQLA         NaN
#  6         NaN               Internal         NaN           #         NaN
#  7         NaN  Internal Counterparty         NaN           #         NaN
#  8         NaN        Prime Brokerage         NaN           #         NaN,
#      Unnamed: 0                          Unnamed: 1  Unnamed: 2   Unnamed: 3  \
#  0          NaN  (6) Excess Collateral (§.22(b)(5))         NaN          NaN
#  1          NaN                                 NaN         NaN          NaN
#  2          NaN                               Field         NaN        Value
#  3          NaN                    Reporting Entity         NaN     LCR Firm
#  4          NaN                            Currency         NaN            *
#  5          NaN                           Converted         NaN            #
#  6          NaN                                 PID         NaN        S.I.9
#  7          NaN                             Product         NaN  Matches PID
#  8          NaN                                 SID         NaN            #
#  9          NaN                         Sub‐Product         NaN            #
#  10         NaN                                SID2         NaN            #
#  11         NaN                        Sub‐Product2         NaN            #
#  12         NaN                        Market Value         NaN            *
#  13         NaN                    Collateral Class         NaN         HQLA
#  14         NaN                            Internal         NaN            #
#  15         NaN               Internal Counterparty         NaN            #
#  16         NaN                     Prime Brokerage         NaN            #
#
#      Unnamed: 4
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8          NaN
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN
#  13         NaN
#  14         NaN
#  15         NaN
#  16         NaN  ,
#      Unnamed: 0 (7) Secured Lending Unwind (Subpart C, §.21)  Unnamed: 1  \
#  0          NaN                                          NaN         NaN
#  1          NaN                                        Field         NaN
#  2          NaN                             Reporting Entity         NaN
#  3          NaN                                     Currency         NaN
#  4          NaN                                    Converted         NaN
#  5          NaN                                          PID         NaN
#  6          NaN                                      Product         NaN
#  7          NaN                                          SID         NaN
#  8          NaN                                  Sub‐Product         NaN
#  9          NaN                              Maturity Amount         NaN
#  10         NaN                              Maturity Bucket         NaN
#  11         NaN                    Effective Maturity Bucket         NaN
#  12         NaN                         Forward Start Amount         NaN
#  13         NaN                         Forward Start Bucket         NaN
#
#                                     Unnamed: 2  Unnamed: 3
#  0                                         NaN         NaN
#  1                                       Value         NaN
#  2                                    LCR Firm         NaN
#  3                                           *         NaN
#  4                                           #         NaN
#  5                       I.S.1, 2, 3, 5, and 6         NaN
#  6                                 Matches PID         NaN
#  7                                           #         NaN
#  8                                           #         NaN
#  9                                           *         NaN
#  10                        <= 30 calendar days         NaN
#  11  NULL or <= 30 calendar days, but not Open         NaN
#  12                                       NULL         NaN
#  13                                       NULL         NaN  ,
#     Unnamed: 0       Collateral Class  Unnamed: 1  \
#  0         NaN       Collateral Value         NaN
#  1         NaN           Unencumbered         NaN
#  2         NaN       Treasury Control         NaN
#  3         NaN               Internal         NaN
#  4         NaN  Internal Counterparty         NaN
#  5         NaN        Prime Brokerage         NaN
#  6         NaN             Settlement         NaN
#  7         NaN                    CID         NaN
#  8         NaN           Counterparty         NaN
#
#                                                  HQLA  Unnamed: 2
#  0                                                  *         NaN
#  1  Y if Effective Maturity Bucket is NULL, otherw...         NaN
#  2                                                  Y         NaN
#  3                                                  #         NaN
#  4                                                  #         NaN
#  5                                                  #         NaN
#  6                                                  #         NaN
#  7                                                  #         NaN
#  8                                                  #         NaN  ,
#      Unnamed: 0                                    Unnamed: 1  Unnamed: 2  \
#  0          NaN  (8) Secured Funding Unwind (Subpart C, §.21)         NaN
#  1          NaN                                           NaN         NaN
#  2          NaN                                         Field         NaN
#  3          NaN                              Reporting Entity         NaN
#  4          NaN                                      Currency         NaN
#  5          NaN                                     Converted         NaN
#  6          NaN                                           PID         NaN
#  7          NaN                                       Product         NaN
#  8          NaN                                           SID         NaN
#  9          NaN                                   Sub‐Product         NaN
#  10         NaN                               Maturity Amount         NaN
#  11         NaN                               Maturity Bucket         NaN
#  12         NaN                          Forward Start Amount         NaN
#  13         NaN                          Forward Start Bucket         NaN
#  14         NaN                              Collateral Class         NaN
#  15         NaN                              Collateral Value         NaN
#  16         NaN                              Treasury Control         NaN
#  17         NaN                                      Internal         NaN
#  18         NaN                         Internal Counterparty         NaN
#  19         NaN                               Prime Brokerage         NaN
#  20         NaN                                    Settlement         NaN
#  21         NaN                                Rehypothecated         NaN
#  22         NaN                                           CID         NaN
#  23         NaN                                  Counterparty         NaN
#
#                                             Unnamed: 3  Unnamed: 4
#  0                                                 NaN         NaN
#  1                                                 NaN         NaN
#  2                                               Value         NaN
#  3                                            LCR Firm         NaN
#  4                                                   *         NaN
#  5                                                   #         NaN
#  6                         O.S.1, 2, 3, 5, 6, 7, and 9         NaN
#  7                                         Matches PID         NaN
#  8                                 Matches Sub‐Product         NaN
#  9   For O.S.7, cannot be Unsettled (Regular Way) o...         NaN
#  10                                                  *         NaN
#  11                                <= 30 calendar days         NaN
#  12                                               NULL         NaN
#  13                                               NULL         NaN
#  14                                               HQLA         NaN
#  15                                                  *         NaN
#  16                                                  Y         NaN
#  17                                                  #         NaN
#  18                                                  #         NaN
#  19                                                  #         NaN
#  20                                                  #         NaN
#  21                                                  #         NaN
#  22                                                  #         NaN
#  23                                                  #         NaN  ,
#     Unnamed: 0                                   Unnamed: 1  Unnamed: 2  \
#  0         NaN  (9) Asset Exchange Unwind (Subpart C, §.21)         NaN
#  1         NaN                                          NaN         NaN
#  2         NaN                                        Field         NaN
#  3         NaN                             Reporting Entity         NaN
#  4         NaN                                     Currency         NaN
#  5         NaN                                    Converted         NaN
#  6         NaN                                          PID         NaN
#  7         NaN                                      Product         NaN
#
#    Unnamed: 3  Unnamed: 4
#  0        NaN         NaN
#  1        NaN         NaN
#  2      Value         NaN
#  3   LCR Firm         NaN
#  4          *         NaN
#  5          #         NaN
#  6      I.S.4         NaN
#  7          #         NaN  ,
#      Unnamed: 0                        SID  Unnamed: 1  \
#  0          NaN                Sub‐Product         NaN
#  1          NaN            Maturity Amount         NaN
#  2          NaN            Maturity Bucket         NaN
#  3          NaN  Effective Maturity Bucket         NaN
#  4          NaN       Forward Start Amount         NaN
#  5          NaN       Forward Start Bucket         NaN
#  6          NaN           Collateral Class         NaN
#  7          NaN           Collateral Value         NaN
#  8          NaN               Unencumbered         NaN
#  9          NaN           Treasury Control         NaN
#  10         NaN                   Internal         NaN
#  11         NaN      Internal Counterparty         NaN
#  12         NaN            Prime Brokerage         NaN
#  13         NaN                 Settlement         NaN
#  14         NaN                        CID         NaN
#  15         NaN               Counterparty         NaN
#
#                                    Matches Sub‐Product  Unnamed: 2
#  0      Level 1 HQLA, Level 2A HQLA, and Level 2B HQLA         NaN
#  1                                                   *         NaN
#  2                                 <= 30 calendar days         NaN
#  3               NULL or <= 30 calendar days, not Open         NaN
#  4                                                NULL         NaN
#  5                                                NULL         NaN
#  6                                                HQLA         NaN
#  7                                                   *         NaN
#  8   Y if Effective Maturity Bucket is NULL, otherw...         NaN
#  9                                                   Y         NaN
#  10                                                  #         NaN
#  11                                                  #         NaN
#  12                                                  #         NaN
#  13                                                  #         NaN
#  14                                                  #         NaN
#  15                                                  #         NaN  ,
#      Unnamed: 0 (10) Stable Retail Deposits (§.32(a)(1))  Unnamed: 1  \
#  0          NaN                                      NaN         NaN
#  1          NaN                                    Field         NaN
#  2          NaN                         Reporting Entity         NaN
#  3          NaN                                 Currency         NaN
#  4          NaN                                Converted         NaN
#  5          NaN                                      PID         NaN
#  6          NaN                                  Product         NaN
#  7          NaN                                      CID         NaN
#  8          NaN                             Counterparty         NaN
#  9          NaN                          Maturity Amount         NaN
#  10         NaN                          Maturity Bucket         NaN
#  11         NaN                         Collateral Class         NaN
#  12         NaN                         Collateral Value         NaN
#  13         NaN                                  Insured         NaN
#  14         NaN                                  Trigger         NaN
#  15         NaN                           Rehypothecated         NaN
#  16         NaN                                 Internal         NaN
#  17         NaN                    Internal Counterparty         NaN
#
#                    Unnamed: 2  Unnamed: 3
#  0                        NaN         NaN
#  1                      Value         NaN
#  2                   LCR Firm         NaN
#  3                          *         NaN
#  4                          #         NaN
#  5                O.D.1 and 2         NaN
#  6                Matches PID         NaN
#  7       Matches Counterparty         NaN
#  8   Retail or Small Business         NaN
#  9                          *         NaN
#  10                         #         NaN
#  11                         #         NaN
#  12                         #         NaN
#  13                      FDIC         NaN
#  14                         #         NaN
#  15                         #         NaN
#  16                         #         NaN
#  17                         #         NaN  ,
#      Unnamed: 0                               Unnamed: 1  Unnamed: 2  \
#  0          NaN  (11) Other Retail Deposits (§.32(a)(2))         NaN
#  1          NaN                                      NaN         NaN
#  2          NaN                                    Field         NaN
#  3          NaN                         Reporting Entity         NaN
#  4          NaN                                 Currency         NaN
#  5          NaN                                Converted         NaN
#  6          NaN                                      PID         NaN
#  7          NaN                                  Product         NaN
#  8          NaN                                      CID         NaN
#  9          NaN                             Counterparty         NaN
#  10         NaN                          Maturity Amount         NaN
#  11         NaN                          Maturity Bucket         NaN
#  12         NaN                         Collateral Class         NaN
#  13         NaN                         Collateral Value         NaN
#  14         NaN                                  Insured         NaN
#  15         NaN                                  Trigger         NaN
#  16         NaN                           Rehypothecated         NaN
#  17         NaN                                 Internal         NaN
#  18         NaN                    Internal Counterparty         NaN
#
#                                         Unnamed: 3  Unnamed: 4
#  0                                             NaN         NaN
#  1                                             NaN         NaN
#  2                                           Value         NaN
#  3                                        LCR Firm         NaN
#  4                                               *         NaN
#  5                                               #         NaN
#  6                                 O.D.1, 2, and 3         NaN
#  7                                     Matches PID         NaN
#  8                            Matches Counterparty         NaN
#  9                        Retail or Small Business         NaN
#  10                                              *         NaN
#  11                                              #         NaN
#  12                                              #         NaN
#  13                                              #         NaN
#  14  Not FDIC for PID = 1 and 2, and # for PID = 3         NaN
#  15                                              #         NaN
#  16                                              #         NaN
#  17                                              #         NaN
#  18                                              #         NaN  ,
#     Unnamed: 0 (12) Insured Placed Retail Deposits (§.32(a)(3))  Unnamed: 1  \
#  0         NaN                                              NaN         NaN
#  1         NaN                                            Field         NaN
#  2         NaN                                 Reporting Entity         NaN
#  3         NaN                                         Currency         NaN
#
#    Unnamed: 2  Unnamed: 3
#  0        NaN         NaN
#  1      Value         NaN
#  2   LCR Firm         NaN
#  3          *         NaN  ,
#      Unnamed: 0              Converted  Unnamed: 1                         #  \
#  0          NaN                    PID         NaN                    O.D.12
#  1          NaN                Product         NaN               Matches PID
#  2          NaN                    CID         NaN      Matches Counterparty
#  3          NaN           Counterparty         NaN  Retail or Small Business
#  4          NaN        Maturity Amount         NaN                         *
#  5          NaN        Maturity Bucket         NaN                         #
#  6          NaN       Collateral Class         NaN                         #
#  7          NaN       Collateral Value         NaN                         #
#  8          NaN                Insured         NaN                      FDIC
#  9          NaN                Trigger         NaN                         #
#  10         NaN         Rehypothecated         NaN                         #
#  11         NaN               Internal         NaN                         #
#  12         NaN  Internal Counterparty         NaN                         #
#
#      Unnamed: 2
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8          NaN
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN  ,
#      Unnamed: 0 (13) Non‐Insured Placed Retail Deposits (§.32(a)(4))  \
#  0          NaN                                                NaN
#  1          NaN                                              Field
#  2          NaN                                   Reporting Entity
#  3          NaN                                           Currency
#  4          NaN                                          Converted
#  5          NaN                                                PID
#  6          NaN                                            Product
#  7          NaN                                                CID
#  8          NaN                                       Counterparty
#  9          NaN                                    Maturity Amount
#  10         NaN                                    Maturity Bucket
#  11         NaN                                   Collateral Class
#  12         NaN                                   Collateral Value
#  13         NaN                                            Insured
#  14         NaN                                            Trigger
#  15         NaN                                     Rehypothecated
#  16         NaN                                           Internal
#  17         NaN                              Internal Counterparty
#
#      Unnamed: 1                Unnamed: 2  Unnamed: 3
#  0          NaN                       NaN         NaN
#  1          NaN                     Value         NaN
#  2          NaN                  LCR Firm         NaN
#  3          NaN                         *         NaN
#  4          NaN                         #         NaN
#  5          NaN                    O.D.12         NaN
#  6          NaN               Matches PID         NaN
#  7          NaN      Matches Counterparty         NaN
#  8          NaN  Retail or Small Business         NaN
#  9          NaN                         *         NaN
#  10         NaN                         #         NaN
#  11         NaN                         #         NaN
#  12         NaN                         #         NaN
#  13         NaN                  Not FDIC         NaN
#  14         NaN                         #         NaN
#  15         NaN                         #         NaN
#  16         NaN                         #         NaN
#  17         NaN                         #         NaN  ,
#     Unnamed: 0                              Unnamed: 1  Unnamed: 2  \
#  0         NaN  (14) Other Retail Funding (§.32(a)(5))         NaN
#  1         NaN                                   Field         NaN
#  2         NaN                        Reporting Entity         NaN
#  3         NaN                                Currency         NaN
#  4         NaN                               Converted         NaN
#  5         NaN                                     PID         NaN
#  6         NaN                                 Product         NaN
#  7         NaN                                     CID         NaN
#  8         NaN                            Counterparty         NaN
#  9         NaN                         Maturity Amount         NaN
#
#                   Unnamed: 3  Unnamed: 4
#  0                       NaN         NaN
#  1                     Value         NaN
#  2                  LCR Firm         NaN
#  3                         *         NaN
#  4                         #         NaN
#  5                    O.D.13         NaN
#  6               Matches PID         NaN
#  7      Matches Counterparty         NaN
#  8  Retail or Small Business         NaN
#  9                         *         NaN  ,
#     Unnamed: 0        Maturity Bucket  Unnamed: 1     #  Unnamed: 2
#  0         NaN       Collateral Class         NaN     #         NaN
#  1         NaN       Collateral Value         NaN     #         NaN
#  2         NaN                Insured         NaN     #         NaN
#  3         NaN                Trigger         NaN     #         NaN
#  4         NaN         Rehypothecated         NaN  NULL         NaN
#  5         NaN               Internal         NaN     #         NaN
#  6         NaN  Internal Counterparty         NaN     #         NaN,
#      Unnamed: 0 (15) Other Retail Funding (§.32(a)(5))  Unnamed: 1  \
#  0          NaN                                    NaN         NaN
#  1          NaN                                  Field         NaN
#  2          NaN                       Reporting Entity         NaN
#  3          NaN                               Currency         NaN
#  4          NaN                              Converted         NaN
#  5          NaN                                    PID         NaN
#  6          NaN                                Product         NaN
#  7          NaN                                    CID         NaN
#  8          NaN                           Counterparty         NaN
#  9          NaN                        Maturity Amount         NaN
#  10         NaN                        Maturity Bucket         NaN
#  11         NaN                   Forward Start Amount         NaN
#  12         NaN                   Forward Start Bucket         NaN
#  13         NaN                       Collateral Class         NaN
#  14         NaN                       Collateral Value         NaN
#  15         NaN                               Internal         NaN
#  16         NaN                  Internal Counterparty         NaN
#  17         NaN                        Prime Brokerage         NaN
#
#                    Unnamed: 2  Unnamed: 3
#  0                        NaN         NaN
#  1                      Value         NaN
#  2                   LCR Firm         NaN
#  3                          *         NaN
#  4                          #         NaN
#  5                     O.O.22         NaN
#  6                Matches PID         NaN
#  7       Matches Counterparty         NaN
#  8   Retail or Small Business         NaN
#  9                          *         NaN
#  10                         #         NaN
#  11                      NULL         NaN
#  12                      NULL         NaN
#  13                         #         NaN
#  14                         #         NaN
#  15                         #         NaN
#  16                         #         NaN
#  17                         #         NaN  ,
#      Unnamed: 0                              Unnamed: 1  Unnamed: 2  \
#  0          NaN  (16) Other Retail Funding (§.32(a)(5))         NaN
#  1          NaN                                     NaN         NaN
#  2          NaN                                   Field         NaN
#  3          NaN                        Reporting Entity         NaN
#  4          NaN                                Currency         NaN
#  5          NaN                               Converted         NaN
#  6          NaN                                     PID         NaN
#  7          NaN                                 Product         NaN
#  8          NaN                                     SID         NaN
#  9          NaN                             Sub‐Product         NaN
#  10         NaN                         Maturity Amount         NaN
#  11         NaN                         Maturity Bucket         NaN
#  12         NaN                    Forward Start Amount         NaN
#  13         NaN                    Forward Start Bucket         NaN
#  14         NaN                        Collateral Class         NaN
#  15         NaN                        Collateral Value         NaN
#
#                                             Unnamed: 3  Unnamed: 4
#  0                                                 NaN         NaN
#  1                                                 NaN         NaN
#  2                                               Value         NaN
#  3                                            LCR Firm         NaN
#  4                                                   *         NaN
#  5                                                   #         NaN
#  6                                  O.S.1, 2, 7, and 9         NaN
#  7                                         Matches PID         NaN
#  8                                                   #         NaN
#  9   For O.S.7, cannot be Unsettled (Regular Way) o...         NaN
#  10                                                  *         NaN
#  11                                                  #         NaN
#  12                                               NULL         NaN
#  13                                               NULL         NaN
#  14                                                  #         NaN
#  15                                                  #         NaN  ,
#          Treasury Control                         #
#  0               Internal                         #
#  1  Internal Counterparty                         #
#  2        Prime Brokerage                         #
#  3             Settlement                         #
#  4         Rehypothecated                         #
#  5                    CID      Matches Counterparty
#  6           Counterparty  Retail or Small Business,
#                 Unnamed: 0 (17) Other Retail Funding (§.32(a)(5))
#  0                   Field                                  Value
#  1        Reporting Entity                               LCR Firm
#  2                Currency                                      *
#  3               Converted                                      #
#  4                     PID                                 O.W.18
#  5                 Product                            Matches PID
#  6                     CID                   Matches Counterparty
#  7            Counterparty               Retail or Small Business
#  8         Maturity Amount                                      *
#  9         Maturity Bucket                    <= 30 calendar days
#  10       Collateral Class                                      #
#  11       Collateral Value                                      #
#  12   Forward Start Amount                                   NULL
#  13   Forward Start Bucket                                   NULL
#  14               Internal                                      #
#  15  Internal Counterparty                                      #
#  16        Prime Brokerage                                      #,
#     (18) Structured Transaction Outflow Amount (§.32(b))
#  0   (The total amount for 32(b) is the relevant co...
#  1                                             O.O.21)
#  2                                         Field Value
#  3                           Reporting Entity LCR Firm
#  4                                          Currency *
#  5                                         Converted #
#  6            PID O.O.21 (adds the incremental amount)
#  7                                 Product Matches PID
#  8                                               CID #
#  9                                      Counterparty #
#  10                                  Maturity Amount *
#  11                Maturity Bucket <= 30 calendar days
#  12                             Forward Start Amount #
#  13                             Forward Start Bucket #
#  14                                 Collateral Class #  ,
#     Unnamed: 0       Collateral Value  Unnamed: 1  #  Unnamed: 2
#  0         NaN               Internal         NaN  #         NaN
#  1         NaN  Internal Counterparty         NaN  #         NaN
#  2         NaN        Prime Brokerage         NaN  #         NaN,
#      Unnamed: 0 (19) Net Derivatives Cash Outflow Amount (§.32(c))  Unnamed: 1  \
#  0          NaN                                                NaN         NaN
#  1          NaN                                              Field         NaN
#  2          NaN                                   Reporting Entity         NaN
#  3          NaN                                           Currency         NaN
#  4          NaN                                          Converted         NaN
#  5          NaN                                                PID         NaN
#  6          NaN                                            Product         NaN
#  7          NaN                                                CID         NaN
# ...
#  15         NaN
#  16         NaN  ,
#                 Unnamed: 0                        (13) O.S. PIDs for item 3.a  \
#  0                   Field                                              Value
#  1        Reporting Entity                                       FR Y‐15 Firm
#  2                Currency                                                  *
#  3               Converted                                                  #
#  4                     PID                            O.S.1, 2, 3, 5, 6, 7, 9
#  5                 Product                                        Matches PID
#  6                     SID                                Matches Sub‐Product
#  7             Sub‐Product  For O.S.7, cannot be Unsettled (Regular Way) o...
#  8         Maturity Amount                                                  *
#  9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
#  10   Forward Start Amount                                               NULL
#  11   Forward Start Bucket                                               NULL
#  12       Collateral Class                                      Level 2B HQLA
#  13       Collateral Value                                                  #
#  14       Treasury Control                                                  #
#  15               Internal                                                  #
#  16  Internal Counterparty                                                  #
#  17        Prime Brokerage                                                  #
#  18             Settlement                                                  #
#  19         Rehypothecated                                                  #
#  20                    CID                               Matches Counterparty
#  21           Counterparty  Non‐Financial Corporate, Sovereign, Central\rB...
#
#      Unnamed: 1
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8          NaN
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN
#  13         NaN
#  14         NaN
#  15         NaN
#  16         NaN
#  17         NaN
#  18         NaN
#  19         NaN
#  20         NaN
#  21         NaN  ,
#                 Unnamed: 0                        (14) O.W. PIDs for item 3.a  \
#  0                   Field                                              Value
#  1        Reporting Entity                                       FR Y‐15 Firm
#  2                Currency                                                  *
#  3               Converted                                                  #
#  4                     PID                                      O.W.1‐7, 9‐19
#  5                 Product                                        Matches PID
#  6                     CID                                                  #
#  7            Counterparty                                                  #
#  8         Maturity Amount                                                  *
#  9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
#  10       Collateral Class                                      Level 2B HQLA
#  11       Collateral Value                                                  #
#  12   Forward Start Amount                                               NULL
#  13   Forward Start Bucket                                               NULL
#  14               Internal                                                  #
#  15  Internal Counterparty                                                  #
#  16        Prime Brokerage                                                  #
#
#      Unnamed: 1
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8          NaN
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN
#  13         NaN
#  14         NaN
#  15         NaN
#  16         NaN  ,
#                     Unnamed: 0  \
#  0                       Field
#  1            Reporting Entity
#  2                    Currency
#  3                   Converted
#  4                         PID
#  5                     Product
#  6                         SID
#  7                 Sub‐Product
#  8             Maturity Amount
#  9             Maturity Bucket
#  10  Effective Maturity Bucket
#  11       Forward Start Amount
#  12       Forward Start Bucket
#  13           Collateral Class
#  14           Collateral Value
#  15               Unencumbered
#  16           Treasury Control
#  17                   Internal
#  18      Internal Counterparty
#  19            Prime Brokerage
#  20                 Settlement
#  21                        CID
#  22               Counterparty
#
#                            (15) O.S. PIDs for item 3.b  Unnamed: 1
#  0                                               Value         NaN
#  1                                        FR Y‐15 Firm         NaN
#  2                                                   *         NaN
#  3                                                   #         NaN
#  4                                               O.S.4         NaN
#  5                                         Matches PID         NaN
#  6   For Collateral Class Level 2B HQLA: 16, 17; Fo...         NaN
#  7                                         Matches SID         NaN
#  8                                                   *         NaN
#  9   Column A: <=30 days\rColumn B:  31 to 90 days\...         NaN
#  10                                                  #         NaN
#  11                                               NULL         NaN
#  12                                               NULL         NaN
#  13                          Level 2B HQLA or Non‐HQLA         NaN
#  14                                                  #         NaN
#  15                                                  #         NaN
#  16                                                  #         NaN
#  17                                                  #         NaN
#  18                                                  #         NaN
#  19                                                  #         NaN
#  20                                                  #         NaN
#  21                                                  #         NaN
#  22                                                  #         NaN  ,
#                 Unnamed: 0                        (16) O.D. PIDs for item 3.c  \
#  0                   Field                                              Value
#  1        Reporting Entity                                       FR Y‐15 Firm
#  2                Currency                                                  *
#  3               Converted                                                  #
#  4                     PID                         O.D.5, 7, 8, 9, 11, 12, 13
#  5                 Product                                        Matches PID
#  6                     CID                               Matches Counterparty
#  7            Counterparty  Bank, Supervised Non‐Bank Financial Entity, De...
#  8         Maturity Amount                                                  *
#  9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
#  10       Collateral Class                                        NULL or Z‐1
#  11       Collateral Value                                               NULL
#  12                Insured                                                  #
#  13                Trigger                                                  #
#  14         Rehypothecated                                                  #
#  15               Internal                                                  #
#  16  Internal Counterparty                                                  #
#
#      Unnamed: 1
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8          NaN
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN
#  13         NaN
#  14         NaN
#  15         NaN
#  16         NaN  ,
#                 Unnamed: 0                        (17) O.W. PIDs for item 3.c  \
#  0                   Field                                              Value
#  1        Reporting Entity                                       FR Y‐15 Firm
#  2                Currency                                                  *
#  3               Converted                                                  #
#  4                     PID                                           O.W.8‐19
#  5                 Product                                        Matches PID
#  6                     CID  For OW.8, 11‐16: #; For O.W.9, 10, 17, 18, 19:...
#  7            Counterparty  For OW.8, 11‐16: #; For O.W.9, 10, 17, 18, 19:...
#  8         Maturity Amount                                                  *
#  9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
#  10       Collateral Class                                               NULL
#  11       Collateral Value                                               NULL
#  12   Forward Start Amount                                               NULL
#  13   Forward Start Bucket                                               NULL
#  14               Internal                                                  #
#  15  Internal Counterparty                                                  #
#  16        Prime Brokerage                                                  #
#
#      Unnamed: 1
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8          NaN
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN
#  13         NaN
#  14         NaN
#  15         NaN
#  16         NaN  ,
#                 Unnamed: 0                          (18) O.D. PIDs for item 4  \
#  0                   Field                                              Value
#  1        Reporting Entity                                       FR Y‐15 Firm
#  2                Currency                                                  *
#  3               Converted                                                  #
#  4                     PID                         O.D.5, 7, 8, 9, 11, 12, 13
#  5                 Product                                        Matches PID
#  6                     CID                               Matches Counterparty
#  7            Counterparty  Non‐Financial Corporate, Sovereign, Central\rB...
#  8         Maturity Amount                                                  *
#  9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
#  10       Collateral Class                                           Non‐HQLA
#  11       Collateral Value                                                  #
#  12                Insured                                                  #
#  13                Trigger                                                  #
#  14         Rehypothecated                                                  #
#  15               Internal                                                  #
#  16  Internal Counterparty                                                  #
#
#      Unnamed: 1
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8          NaN
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN
#  13         NaN
#  14         NaN
#  15         NaN
#  16         NaN  ,
#                 Unnamed: 0                          (19) O.S. PIDs for item 4  \
#  0                   Field                                              Value
#  1        Reporting Entity                                       FR Y‐15 Firm
#  2                Currency                                                  *
#  3               Converted                                                  #
#  4                     PID                              O.S.1, 2, 5, 6, 7 , 9
#  5                 Product                                        Matches PID
#  6                     SID                                Matches Sub‐Product
#  7             Sub‐Product  For O.S.7, cannot be Unsettled (Regular Way) o...
#  8         Maturity Amount                                                  *
#  9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
#  10   Forward Start Amount                                               NULL
#  11   Forward Start Bucket                                               NULL
#  12       Collateral Class                        Not Level 1, 2A, or 2B HQLA
#  13       Collateral Value                                                  #
#  14       Treasury Control                                                  #
#  15               Internal                                                  #
#  16  Internal Counterparty                                                  #
#  17        Prime Brokerage                                                  #
#  18             Settlement                                                  #
#  19         Rehypothecated                                                  #
#  20                    CID                               Matches Counterparty
#  21           Counterparty  Non‐Financial Corporate, Sovereign, Central\rB...
#
#      Unnamed: 1
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8          NaN
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN
#  13         NaN
#  14         NaN
#  15         NaN
#  16         NaN
#  17         NaN
#  18         NaN
#  19         NaN
#  20         NaN
#  21         NaN  ,
#                 Unnamed: 0                          (20) O.W. PIDs for item 4  \
#  0                   Field                                              Value
#  1        Reporting Entity                                       FR Y‐15 Firm
#  2                Currency                                                  *
#  3               Converted                                                  #
#  4                     PID                                            O.W.1‐7
#  5                 Product                                        Matches PID
#  6                     CID                                                  #
#  7            Counterparty                                                  #
#  8         Maturity Amount                                                  *
#  9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
#  10       Collateral Class                        Not Level 1, 2A, or 2B HQLA
#  11       Collateral Value                                                  #
#  12   Forward Start Amount                                               NULL
#  13   Forward Start Bucket                                               NULL
#  14               Internal                                                  #
#  15  Internal Counterparty                                                  #
#  16        Prime Brokerage                                                  #
#
#      Unnamed: 1
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8          NaN
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN
#  13         NaN
#  14         NaN
#  15         NaN
#  16         NaN  ]

# %%
df_tables = tabula.read_pdf(File, pages = "all", multiple_tables=True, stream = True, lattice =True, encoding='utf-8')
# Out:
# Got stderr: Sep 20, 2020 3:34:17 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+3409 (3409) in font GKPCDN+Cambria
# Sep 20, 2020 3:34:17 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+3404 (3404) in font CNMILO+Cambria
# Sep 20, 2020 3:34:17 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+4666 (4666) in font CNMILO+Cambria
# Sep 20, 2020 3:34:17 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+3398 (3398) in font CNMILO+Cambria
# Sep 20, 2020 3:34:17 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+4667 (4667) in font CNMILO+Cambria
# Sep 20, 2020 3:34:17 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+3397 (3397) in font CNMILO+Cambria
# Sep 20, 2020 3:34:17 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+4670 (4670) in font CNMILO+Cambria
# Sep 20, 2020 3:34:17 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+4671 (4671) in font CNMILO+Cambria
# Sep 20, 2020 3:34:17 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+3533 (3533) in font CNMILO+Cambria
# Sep 20, 2020 3:34:17 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+3040 (3040) in font CNMILO+Cambria
# Sep 20, 2020 3:34:17 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+3041 (3041) in font CNMILO+Cambria
# Sep 20, 2020 3:34:17 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+2880 (2880) in font CNMILO+Cambria
# Sep 20, 2020 3:34:17 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+2869 (2869) in font CNMILO+Cambria
# Sep 20, 2020 3:34:17 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+4668 (4668) in font CNMILO+Cambria
# Sep 20, 2020 3:34:17 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+4669 (4669) in font CNMILO+Cambria
# Sep 20, 2020 3:34:17 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+2871 (2871) in font CNMILO+Cambria
# Sep 20, 2020 3:34:17 PM org.apache.pdfbox.pdmodel.font.PDType0Font toUnicode
# WARNING: No Unicode mapping for CID+2868 (2868) in font CNMILO+Cambria

# %% [markdown]
# This returned a list of DataFrames one for each table as shown below:

# %%
print(df_tables)
# Out:
# [   Unnamed: 0         Unnamed: 1             Unnamed: 2
# 0         NaN         Frequency3  Timing of\rSubmission
# 1         NaN                NaN                    NaN
# 2         NaN  Each Business Day                    T+2
# 3         NaN           Monthly4                    T+2
# 4         NaN           Monthly5                   T+10
# 5         NaN                NaN                    NaN,   O.D fields: Reporting Currency Converted    PID          Product  \
# 0         NaN    Entity   Amount    Bucket  Class            Value
# 1         NaN       NaN      NaN       NaN    NaN              NaN
# 2   Sample 1:      BANK      USD        No      4      Operational
# 3   Sample 2:      BANK      USD        No      5  Non‐operational
# 4   Sample 3:      BANK      USD        No      5  Non‐operational
#
#             SID              Sub‐Product Maturity Maturity.1  Collateral  \
# 0  Counterparty                      NaN      NaN        NaN         NaN
# 1           NaN                      NaN      NaN        NaN         NaN
# 2             3  Non‐financial corporate    1,000       Open         NaN
# 3             3  Non‐financial corporate      500       Open         NaN
# 4             3  Non‐financial corporate      750      Day 5         NaN
#
#    Collateral.1    Insured Trigger  Rehyp'd Internal  Internal.1
# 0           NaN        NaN     NaN      NaN      NaN         NaN
# 1           NaN        NaN     NaN      NaN      NaN         NaN
# 2           NaN       FDIC       N      NaN        N         NaN
# 3           NaN  Uninsured       N      NaN        N         NaN
# 4           NaN  Uninsured       N      NaN        N         NaN  , Empty DataFrame
# Columns: [Other inflows]
# Index: [], Empty DataFrame
# Columns: [Other outflows]
# Index: [],   O.W fields: Reporting Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0         NaN       NaN   Currency  Converted        PID
# 1         NaN    Entity     Bucket     Amount      Class
# 2         NaN       NaN        NaN        NaN        NaN
# 3         NaN       NaN        NaN        NaN        NaN
# 4   Sample 1:    PARENT        USD         No         12
# 5   Sample 2:    PARENT        GBP         No         12
# 6   Sample 3:    PARENT        GBP         No         12
#
#              Unnamed: 3  Maturity Maturity.1    Collateral Collateral.1  \
# 0               Product  Internal        NaN           NaN          NaN
# 1                 Value    Amount     Bucket  Counterparty    Brokerage
# 2                   NaN       NaN        NaN           NaN          NaN
# 3                   NaN       NaN        NaN           NaN          NaN
# 4  LTD ‐ Non‐Structured  >4Y_<=5Y      1,500           NaN          NaN
# 5  LTD ‐ Non‐Structured       >5Y      2,000           NaN          NaN
# 6  LTD ‐ Non‐Structured  >1Y_<=2Y        250           NaN          NaN
#
#    Fwd Start  Fwd Start.1 Unnamed: 4  Internal Prime
# 0        NaN          NaN        NaN       NaN   NaN
# 1        NaN          NaN        NaN       NaN   NaN
# 2        NaN          NaN        NaN       NaN   NaN
# 3        NaN          NaN        NaN       NaN   NaN
# 4        NaN          NaN          N       NaN     N
# 5        NaN          NaN          N       NaN     N
# 6        NaN          NaN          N       NaN     N  ,           Unnamed: 0 Unnamed: 1  \
# 0             Prefix          .
# 1       I\r(Inflows)          .
# 2      O\r(Outflows)          .
# 3  S\r(Supplemental)          .
#
#                                           Unnamed: 2 Unnamed: 3 Product
# 0                                              Table          .       #
# 1  A (Assets)\rU (Unsecured)\rS (Secured)\rO (Other)          .       #
# 2  D (Deposits)\rW (Wholesale)\rS (Secured)\rO (O...          .       #
# 3     I (Informational Items)\rFX (Foreign Exchange)          .       #  ,   I.A fields: Reporting Currency Converted    PID   Product     SID    Sub‐  \
# 0         NaN    Entity  Product    Bucket  Value     Value  Amount  Bucket
# 1         NaN       NaN      NaN       NaN    NaN       NaN     NaN     NaN
# 2     Sample:      BANK      USD        No      2  Capacity       9    FHLB
#
#   Maturity   Market  Lendable  Fwd Start  Fwd Start.1 Collateral Treasury
# 0    Class  Control       NaN        NaN          NaN        NaN      NaN
# 1      NaN      NaN       NaN        NaN          NaN        NaN      NaN
# 2     Open      150     100.0        NaN          NaN        L‐3        Y  ,    Unnamed: 0
# 0         NaN,    Unnamed: 0
# 0         NaN,    Unnamed: 0
# 0         NaN, Empty DataFrame
# Columns: [Unnamed: 0]
# Index: [], Empty DataFrame
# Columns: [Unnamed: 0]
# Index: [], Empty DataFrame
# Columns: [Unnamed: 0]
# Index: [], Empty DataFrame
# Columns: [Unnamed: 0]
# Index: [],    Unnamed: 0                      Outflow adjustment percentage  Unnamed: 1  \
# 0         NaN  Global systemically important BHC or GSIB depo...         NaN
# 1         NaN                                                NaN         NaN
# 2         NaN            Category II Board‐regulated institution         NaN
# 3         NaN                                                NaN         NaN
# 4         NaN  Category III Board‐regulated institution with ...         NaN
# 5         NaN                                                NaN         NaN
# 6         NaN  Category III Board‐regulated institution with ...         NaN
# 7         NaN  Category IV Board‐regulated institution with $...         NaN
#
#      Unnamed: 2  Unnamed: 3
# 0  100\rpercent         NaN
# 1           NaN         NaN
# 2  100\rpercent         NaN
# 3           NaN         NaN
# 4  100\rpercent         NaN
# 5           NaN         NaN
# 6   85\rpercent         NaN
# 7   70\rpercent         NaN  ,     Unnamed: 0 (1) High‐Quality Liquid Assets (Subpart C, §.20‐.22)  \
# 0          NaN                                                NaN
# 1          NaN                                              Field
# 2          NaN                                   Reporting Entity
# 3          NaN                                           Currency
# 4          NaN                                          Converted
# 5          NaN                                                PID
# 6          NaN                                            Product
# 7          NaN                                                SID
# 8          NaN                                        Sub‐Product
# 9          NaN                                       Market Value
# 10         NaN                                     Lendable Value
# 11         NaN                                    Maturity Bucket
# 12         NaN                               Forward Start Amount
# 13         NaN                               Forward Start Bucket
# 14         NaN                                   Collateral Class
# 15         NaN                                   Treasury Control
#
#     Unnamed: 1                     Unnamed: 2  Unnamed: 3
# 0          NaN                            NaN         NaN
# 1          NaN                          Value         NaN
# 2          NaN                       LCR Firm         NaN
# 3          NaN                              *         NaN
# 4          NaN                              #         NaN
# 5          NaN                I.A.1, 2, and 3         NaN
# 6          NaN                    Matches PID         NaN
# 7          NaN            Matches Sub‐Product         NaN
# 8          NaN                 Not Other Cash         NaN
# 9          NaN                              *         NaN
# 10         NaN                              #         NaN
# 11         NaN    Open for I.A.3, # otherwise         NaN
# 12         NaN                           NULL         NaN
# 13         NaN                           NULL         NaN
# 14         NaN  HQLA (except A‐0‐Q for I.A.2)         NaN
# 15         NaN                              Y         NaN  ,     Unnamed: 0 (2) Rehypothecatable Collateral (Subpart C, §.20‐.22)  \
# 0          NaN                                                NaN
# 1          NaN                                              Field
# 2          NaN                                   Reporting Entity
# 3          NaN                                           Currency
# 4          NaN                                          Converted
# 5          NaN                                                PID
# 6          NaN                                            Product
# 7          NaN                                                SID
# 8          NaN                                        Sub‐Product
# 9          NaN                                    Maturity Amount
# 10         NaN                                    Maturity Bucket
# 11         NaN                          Effective Maturity Bucket
# 12         NaN                               Forward Start Amount
# 13         NaN                               Forward Start Bucket
# 14         NaN                                   Collateral Class
# 15         NaN                                   Collateral Value
# 16         NaN                                       Unencumbered
# 17         NaN                                   Treasury Control
# 18         NaN                                           Internal
# 19         NaN                              Internal Counterparty
# 20         NaN                                    Prime Brokerage
# 21         NaN                                         Settlement
# 22         NaN                                                CID
# 23         NaN                                       Counterparty
#
#     Unnamed: 1                Unnamed: 2  Unnamed: 3
# 0          NaN                       NaN         NaN
# 1          NaN                     Value         NaN
# 2          NaN                  LCR Firm         NaN
# 3          NaN                         *         NaN
# 4          NaN                         #         NaN
# 5          NaN  I.S.1, 2, 3, 4, 5, and 6         NaN
# 6          NaN               Matches PID         NaN
# 7          NaN                         #         NaN
# 8          NaN                         #         NaN
# 9          NaN                         #         NaN
# 10         NaN                         #         NaN
# 11         NaN                      NULL         NaN
# 12         NaN                      NULL         NaN
# 13         NaN                      NULL         NaN
# 14         NaN       HQLA (except A‐0‐Q)         NaN
# 15         NaN                         *         NaN
# 16         NaN                         Y         NaN
# 17         NaN                         Y         NaN
# 18         NaN                         #         NaN
# 19         NaN                         #         NaN
# 20         NaN                         #         NaN
# 21         NaN                         #         NaN
# 22         NaN                         #         NaN
# 23         NaN                         #         NaN  ,     Unnamed: 0 (3) Rehypothecatable Collateral (Subpart C, §.20‐.22)  \
# 0          NaN                                                NaN
# 1          NaN                                              Field
# 2          NaN                                   Reporting Entity
# 3          NaN                                           Currency
# 4          NaN                                          Converted
# 5          NaN                                                PID
# 6          NaN                                            Product
# 7          NaN                                                SID
# 8          NaN                                        Sub‐Product
# 9          NaN                                               SID2
# 10         NaN                                       Sub‐Product2
# 11         NaN                                       Market Value
# 12         NaN                                   Collateral Class
# 13         NaN                                           Internal
# 14         NaN                              Internal Counterparty
# 15         NaN                                    Prime Brokerage
#
#     Unnamed: 1                         Unnamed: 2  Unnamed: 3
# 0          NaN                                NaN         NaN
# 1          NaN                              Value         NaN
# 2          NaN                           LCR Firm         NaN
# 3          NaN                                  *         NaN
# 4          NaN                                  #         NaN
# 5          NaN                        S.I.3 and 6         NaN
# 6          NaN                        Matches PID         NaN
# 7          NaN                Matches Sub‐Product         NaN
# 8          NaN  Unencumbered and Treasury Control         NaN
# 9          NaN                                  #         NaN
# 10         NaN                                  #         NaN
# 11         NaN                                  *         NaN
# 12         NaN                               HQLA         NaN
# 13         NaN                                  #         NaN
# 14         NaN                                  #         NaN
# 15         NaN                                  #         NaN  ,     Unnamed: 0                                Unnamed: 1  Unnamed: 2  \
# 0          NaN  (4) Excluded Sub HQLA (§.22(b)(3)and(4))         NaN
# 1          NaN                                     Field         NaN
# 2          NaN                          Reporting Entity         NaN
# 3          NaN                                  Currency         NaN
# 4          NaN                                 Converted         NaN
# 5          NaN                                       PID         NaN
# 6          NaN                                   Product         NaN
# 7          NaN                                       SID         NaN
# 8          NaN                               Sub‐Product         NaN
# 9          NaN                                      SID2         NaN
# 10         NaN                              Sub‐Product2         NaN
# 11         NaN                              Market Value         NaN
# 12         NaN                          Collateral Class         NaN
# 13         NaN                                  Internal         NaN
# 14         NaN                     Internal Counterparty         NaN
# 15         NaN                           Prime Brokerage         NaN
#
#      Unnamed: 3  Unnamed: 4
# 0           NaN         NaN
# 1         Value         NaN
# 2      LCR Firm         NaN
# 3             *         NaN
# 4             #         NaN
# 5        S.I.19         NaN
# 6   Matches PID         NaN
# 7             #         NaN
# 8             #         NaN
# 9             #         NaN
# 10            #         NaN
# 11            *         NaN
# 12         HQLA         NaN
# 13            #         NaN
# 14            #         NaN
# 15            #         NaN  ,    Unnamed: 0                                         Unnamed: 1  Unnamed: 2  \
# 0         NaN  (5) Early Hedge Termination Outflows (§.22(a)(3))         NaN
# 1         NaN                                                NaN         NaN
# 2         NaN                                              Field         NaN
# 3         NaN                                   Reporting Entity         NaN
# 4         NaN                                           Currency         NaN
# 5         NaN                                          Converted         NaN
# 6         NaN                                                PID         NaN
#
#   Unnamed: 3  Unnamed: 4
# 0        NaN         NaN
# 1        NaN         NaN
# 2      Value         NaN
# 3   LCR Firm         NaN
# 4          *         NaN
# 5          #         NaN
# 6     S.I.21         NaN  ,    Unnamed: 0                Product  Unnamed: 1 Matches PID  Unnamed: 2
# 0         NaN                    SID         NaN           #         NaN
# 1         NaN            Sub‐Product         NaN           #         NaN
# 2         NaN                   SID2         NaN           #         NaN
# 3         NaN           Sub‐Product2         NaN           #         NaN
# 4         NaN           Market Value         NaN           *         NaN
# 5         NaN       Collateral Class         NaN        HQLA         NaN
# 6         NaN               Internal         NaN           #         NaN
# 7         NaN  Internal Counterparty         NaN           #         NaN
# 8         NaN        Prime Brokerage         NaN           #         NaN,     Unnamed: 0                          Unnamed: 1  Unnamed: 2   Unnamed: 3  \
# 0          NaN  (6) Excess Collateral (§.22(b)(5))         NaN          NaN
# 1          NaN                                 NaN         NaN          NaN
# 2          NaN                               Field         NaN        Value
# 3          NaN                    Reporting Entity         NaN     LCR Firm
# 4          NaN                            Currency         NaN            *
# 5          NaN                           Converted         NaN            #
# 6          NaN                                 PID         NaN        S.I.9
# 7          NaN                             Product         NaN  Matches PID
# 8          NaN                                 SID         NaN            #
# 9          NaN                         Sub‐Product         NaN            #
# 10         NaN                                SID2         NaN            #
# 11         NaN                        Sub‐Product2         NaN            #
# 12         NaN                        Market Value         NaN            *
# 13         NaN                    Collateral Class         NaN         HQLA
# 14         NaN                            Internal         NaN            #
# 15         NaN               Internal Counterparty         NaN            #
# 16         NaN                     Prime Brokerage         NaN            #
#
#     Unnamed: 4
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN  ,     Unnamed: 0 (7) Secured Lending Unwind (Subpart C, §.21)  Unnamed: 1  \
# 0          NaN                                          NaN         NaN
# 1          NaN                                        Field         NaN
# 2          NaN                             Reporting Entity         NaN
# 3          NaN                                     Currency         NaN
# 4          NaN                                    Converted         NaN
# 5          NaN                                          PID         NaN
# 6          NaN                                      Product         NaN
# 7          NaN                                          SID         NaN
# 8          NaN                                  Sub‐Product         NaN
# 9          NaN                              Maturity Amount         NaN
# 10         NaN                              Maturity Bucket         NaN
# 11         NaN                    Effective Maturity Bucket         NaN
# 12         NaN                         Forward Start Amount         NaN
# 13         NaN                         Forward Start Bucket         NaN
#
#                                    Unnamed: 2  Unnamed: 3
# 0                                         NaN         NaN
# 1                                       Value         NaN
# 2                                    LCR Firm         NaN
# 3                                           *         NaN
# 4                                           #         NaN
# 5                       I.S.1, 2, 3, 5, and 6         NaN
# 6                                 Matches PID         NaN
# 7                                           #         NaN
# 8                                           #         NaN
# 9                                           *         NaN
# 10                        <= 30 calendar days         NaN
# 11  NULL or <= 30 calendar days, but not Open         NaN
# 12                                       NULL         NaN
# 13                                       NULL         NaN  ,    Unnamed: 0       Collateral Class  Unnamed: 1  \
# 0         NaN       Collateral Value         NaN
# 1         NaN           Unencumbered         NaN
# 2         NaN       Treasury Control         NaN
# 3         NaN               Internal         NaN
# 4         NaN  Internal Counterparty         NaN
# 5         NaN        Prime Brokerage         NaN
# 6         NaN             Settlement         NaN
# 7         NaN                    CID         NaN
# 8         NaN           Counterparty         NaN
#
#                                                 HQLA  Unnamed: 2
# 0                                                  *         NaN
# 1  Y if Effective Maturity Bucket is NULL, otherw...         NaN
# 2                                                  Y         NaN
# 3                                                  #         NaN
# 4                                                  #         NaN
# 5                                                  #         NaN
# 6                                                  #         NaN
# 7                                                  #         NaN
# 8                                                  #         NaN  ,     Unnamed: 0                                    Unnamed: 1  Unnamed: 2  \
# 0          NaN  (8) Secured Funding Unwind (Subpart C, §.21)         NaN
# 1          NaN                                           NaN         NaN
# 2          NaN                                         Field         NaN
# 3          NaN                              Reporting Entity         NaN
# 4          NaN                                      Currency         NaN
# 5          NaN                                     Converted         NaN
# 6          NaN                                           PID         NaN
# 7          NaN                                       Product         NaN
# 8          NaN                                           SID         NaN
# 9          NaN                                   Sub‐Product         NaN
# 10         NaN                               Maturity Amount         NaN
# 11         NaN                               Maturity Bucket         NaN
# 12         NaN                          Forward Start Amount         NaN
# 13         NaN                          Forward Start Bucket         NaN
# 14         NaN                              Collateral Class         NaN
# 15         NaN                              Collateral Value         NaN
# 16         NaN                              Treasury Control         NaN
# 17         NaN                                      Internal         NaN
# 18         NaN                         Internal Counterparty         NaN
# 19         NaN                               Prime Brokerage         NaN
# 20         NaN                                    Settlement         NaN
# 21         NaN                                Rehypothecated         NaN
# 22         NaN                                           CID         NaN
# 23         NaN                                  Counterparty         NaN
#
#                                            Unnamed: 3  Unnamed: 4
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                               Value         NaN
# 3                                            LCR Firm         NaN
# 4                                                   *         NaN
# 5                                                   #         NaN
# 6                         O.S.1, 2, 3, 5, 6, 7, and 9         NaN
# 7                                         Matches PID         NaN
# 8                                 Matches Sub‐Product         NaN
# 9   For O.S.7, cannot be Unsettled (Regular Way) o...         NaN
# 10                                                  *         NaN
# 11                                <= 30 calendar days         NaN
# 12                                               NULL         NaN
# 13                                               NULL         NaN
# 14                                               HQLA         NaN
# 15                                                  *         NaN
# 16                                                  Y         NaN
# 17                                                  #         NaN
# 18                                                  #         NaN
# 19                                                  #         NaN
# 20                                                  #         NaN
# 21                                                  #         NaN
# 22                                                  #         NaN
# 23                                                  #         NaN  ,    Unnamed: 0                                   Unnamed: 1  Unnamed: 2  \
# 0         NaN  (9) Asset Exchange Unwind (Subpart C, §.21)         NaN
# 1         NaN                                          NaN         NaN
# 2         NaN                                        Field         NaN
# 3         NaN                             Reporting Entity         NaN
# 4         NaN                                     Currency         NaN
# 5         NaN                                    Converted         NaN
# 6         NaN                                          PID         NaN
# 7         NaN                                      Product         NaN
#
#   Unnamed: 3  Unnamed: 4
# 0        NaN         NaN
# 1        NaN         NaN
# 2      Value         NaN
# 3   LCR Firm         NaN
# 4          *         NaN
# 5          #         NaN
# 6      I.S.4         NaN
# 7          #         NaN  ,     Unnamed: 0                        SID  Unnamed: 1  \
# 0          NaN                Sub‐Product         NaN
# 1          NaN            Maturity Amount         NaN
# 2          NaN            Maturity Bucket         NaN
# 3          NaN  Effective Maturity Bucket         NaN
# 4          NaN       Forward Start Amount         NaN
# 5          NaN       Forward Start Bucket         NaN
# 6          NaN           Collateral Class         NaN
# 7          NaN           Collateral Value         NaN
# 8          NaN               Unencumbered         NaN
# 9          NaN           Treasury Control         NaN
# 10         NaN                   Internal         NaN
# 11         NaN      Internal Counterparty         NaN
# 12         NaN            Prime Brokerage         NaN
# 13         NaN                 Settlement         NaN
# 14         NaN                        CID         NaN
# 15         NaN               Counterparty         NaN
#
#                                   Matches Sub‐Product  Unnamed: 2
# 0      Level 1 HQLA, Level 2A HQLA, and Level 2B HQLA         NaN
# 1                                                   *         NaN
# 2                                 <= 30 calendar days         NaN
# 3               NULL or <= 30 calendar days, not Open         NaN
# 4                                                NULL         NaN
# 5                                                NULL         NaN
# 6                                                HQLA         NaN
# 7                                                   *         NaN
# 8   Y if Effective Maturity Bucket is NULL, otherw...         NaN
# 9                                                   Y         NaN
# 10                                                  #         NaN
# 11                                                  #         NaN
# 12                                                  #         NaN
# 13                                                  #         NaN
# 14                                                  #         NaN
# 15                                                  #         NaN  ,     Unnamed: 0 (10) Stable Retail Deposits (§.32(a)(1))  Unnamed: 1  \
# 0          NaN                                      NaN         NaN
# 1          NaN                                    Field         NaN
# 2          NaN                         Reporting Entity         NaN
# 3          NaN                                 Currency         NaN
# 4          NaN                                Converted         NaN
# 5          NaN                                      PID         NaN
# 6          NaN                                  Product         NaN
# 7          NaN                                      CID         NaN
# 8          NaN                             Counterparty         NaN
# 9          NaN                          Maturity Amount         NaN
# 10         NaN                          Maturity Bucket         NaN
# 11         NaN                         Collateral Class         NaN
# 12         NaN                         Collateral Value         NaN
# 13         NaN                                  Insured         NaN
# 14         NaN                                  Trigger         NaN
# 15         NaN                           Rehypothecated         NaN
# 16         NaN                                 Internal         NaN
# 17         NaN                    Internal Counterparty         NaN
#
#                   Unnamed: 2  Unnamed: 3
# 0                        NaN         NaN
# 1                      Value         NaN
# 2                   LCR Firm         NaN
# 3                          *         NaN
# 4                          #         NaN
# 5                O.D.1 and 2         NaN
# 6                Matches PID         NaN
# 7       Matches Counterparty         NaN
# 8   Retail or Small Business         NaN
# 9                          *         NaN
# 10                         #         NaN
# 11                         #         NaN
# 12                         #         NaN
# 13                      FDIC         NaN
# 14                         #         NaN
# 15                         #         NaN
# 16                         #         NaN
# 17                         #         NaN  ,     Unnamed: 0                               Unnamed: 1  Unnamed: 2  \
# 0          NaN  (11) Other Retail Deposits (§.32(a)(2))         NaN
# 1          NaN                                      NaN         NaN
# 2          NaN                                    Field         NaN
# 3          NaN                         Reporting Entity         NaN
# 4          NaN                                 Currency         NaN
# 5          NaN                                Converted         NaN
# 6          NaN                                      PID         NaN
# 7          NaN                                  Product         NaN
# 8          NaN                                      CID         NaN
# 9          NaN                             Counterparty         NaN
# 10         NaN                          Maturity Amount         NaN
# 11         NaN                          Maturity Bucket         NaN
# 12         NaN                         Collateral Class         NaN
# 13         NaN                         Collateral Value         NaN
# 14         NaN                                  Insured         NaN
# 15         NaN                                  Trigger         NaN
# 16         NaN                           Rehypothecated         NaN
# 17         NaN                                 Internal         NaN
# 18         NaN                    Internal Counterparty         NaN
#
#                                        Unnamed: 3  Unnamed: 4
# 0                                             NaN         NaN
# 1                                             NaN         NaN
# 2                                           Value         NaN
# 3                                        LCR Firm         NaN
# 4                                               *         NaN
# 5                                               #         NaN
# 6                                 O.D.1, 2, and 3         NaN
# 7                                     Matches PID         NaN
# 8                            Matches Counterparty         NaN
# 9                        Retail or Small Business         NaN
# 10                                              *         NaN
# 11                                              #         NaN
# 12                                              #         NaN
# 13                                              #         NaN
# 14  Not FDIC for PID = 1 and 2, and # for PID = 3         NaN
# 15                                              #         NaN
# 16                                              #         NaN
# 17                                              #         NaN
# 18                                              #         NaN  ,    Unnamed: 0 (12) Insured Placed Retail Deposits (§.32(a)(3))  Unnamed: 1  \
# 0         NaN                                              NaN         NaN
# 1         NaN                                            Field         NaN
# 2         NaN                                 Reporting Entity         NaN
# 3         NaN                                         Currency         NaN
#
#   Unnamed: 2  Unnamed: 3
# 0        NaN         NaN
# 1      Value         NaN
# 2   LCR Firm         NaN
# 3          *         NaN  ,     Unnamed: 0              Converted  Unnamed: 1                         #  \
# 0          NaN                    PID         NaN                    O.D.12
# 1          NaN                Product         NaN               Matches PID
# 2          NaN                    CID         NaN      Matches Counterparty
# 3          NaN           Counterparty         NaN  Retail or Small Business
# 4          NaN        Maturity Amount         NaN                         *
# 5          NaN        Maturity Bucket         NaN                         #
# 6          NaN       Collateral Class         NaN                         #
# 7          NaN       Collateral Value         NaN                         #
# 8          NaN                Insured         NaN                      FDIC
# 9          NaN                Trigger         NaN                         #
# 10         NaN         Rehypothecated         NaN                         #
# 11         NaN               Internal         NaN                         #
# 12         NaN  Internal Counterparty         NaN                         #
#
#     Unnamed: 2
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN  ,     Unnamed: 0 (13) Non‐Insured Placed Retail Deposits (§.32(a)(4))  \
# 0          NaN                                                NaN
# 1          NaN                                              Field
# 2          NaN                                   Reporting Entity
# 3          NaN                                           Currency
# 4          NaN                                          Converted
# 5          NaN                                                PID
# 6          NaN                                            Product
# 7          NaN                                                CID
# 8          NaN                                       Counterparty
# 9          NaN                                    Maturity Amount
# 10         NaN                                    Maturity Bucket
# 11         NaN                                   Collateral Class
# 12         NaN                                   Collateral Value
# 13         NaN                                            Insured
# 14         NaN                                            Trigger
# 15         NaN                                     Rehypothecated
# 16         NaN                                           Internal
# 17         NaN                              Internal Counterparty
#
#     Unnamed: 1                Unnamed: 2  Unnamed: 3
# 0          NaN                       NaN         NaN
# 1          NaN                     Value         NaN
# 2          NaN                  LCR Firm         NaN
# 3          NaN                         *         NaN
# 4          NaN                         #         NaN
# 5          NaN                    O.D.12         NaN
# 6          NaN               Matches PID         NaN
# 7          NaN      Matches Counterparty         NaN
# 8          NaN  Retail or Small Business         NaN
# 9          NaN                         *         NaN
# 10         NaN                         #         NaN
# 11         NaN                         #         NaN
# 12         NaN                         #         NaN
# 13         NaN                  Not FDIC         NaN
# 14         NaN                         #         NaN
# 15         NaN                         #         NaN
# 16         NaN                         #         NaN
# 17         NaN                         #         NaN  ,    Unnamed: 0                              Unnamed: 1  Unnamed: 2  \
# 0         NaN  (14) Other Retail Funding (§.32(a)(5))         NaN
# 1         NaN                                   Field         NaN
# 2         NaN                        Reporting Entity         NaN
# 3         NaN                                Currency         NaN
# 4         NaN                               Converted         NaN
# 5         NaN                                     PID         NaN
# 6         NaN                                 Product         NaN
# 7         NaN                                     CID         NaN
# 8         NaN                            Counterparty         NaN
# 9         NaN                         Maturity Amount         NaN
#
#                  Unnamed: 3  Unnamed: 4
# 0                       NaN         NaN
# 1                     Value         NaN
# 2                  LCR Firm         NaN
# 3                         *         NaN
# 4                         #         NaN
# 5                    O.D.13         NaN
# 6               Matches PID         NaN
# 7      Matches Counterparty         NaN
# 8  Retail or Small Business         NaN
# 9                         *         NaN  ,    Unnamed: 0        Maturity Bucket  Unnamed: 1     #  Unnamed: 2
# 0         NaN       Collateral Class         NaN     #         NaN
# 1         NaN       Collateral Value         NaN     #         NaN
# 2         NaN                Insured         NaN     #         NaN
# 3         NaN                Trigger         NaN     #         NaN
# 4         NaN         Rehypothecated         NaN  NULL         NaN
# 5         NaN               Internal         NaN     #         NaN
# 6         NaN  Internal Counterparty         NaN     #         NaN,     Unnamed: 0 (15) Other Retail Funding (§.32(a)(5))  Unnamed: 1  \
# 0          NaN                                    NaN         NaN
# 1          NaN                                  Field         NaN
# 2          NaN                       Reporting Entity         NaN
# 3          NaN                               Currency         NaN
# 4          NaN                              Converted         NaN
# 5          NaN                                    PID         NaN
# 6          NaN                                Product         NaN
# 7          NaN                                    CID         NaN
# 8          NaN                           Counterparty         NaN
# 9          NaN                        Maturity Amount         NaN
# 10         NaN                        Maturity Bucket         NaN
# 11         NaN                   Forward Start Amount         NaN
# 12         NaN                   Forward Start Bucket         NaN
# 13         NaN                       Collateral Class         NaN
# 14         NaN                       Collateral Value         NaN
# 15         NaN                               Internal         NaN
# 16         NaN                  Internal Counterparty         NaN
# 17         NaN                        Prime Brokerage         NaN
#
#                   Unnamed: 2  Unnamed: 3
# 0                        NaN         NaN
# 1                      Value         NaN
# 2                   LCR Firm         NaN
# 3                          *         NaN
# 4                          #         NaN
# 5                     O.O.22         NaN
# 6                Matches PID         NaN
# 7       Matches Counterparty         NaN
# 8   Retail or Small Business         NaN
# 9                          *         NaN
# 10                         #         NaN
# 11                      NULL         NaN
# 12                      NULL         NaN
# 13                         #         NaN
# 14                         #         NaN
# 15                         #         NaN
# 16                         #         NaN
# 17                         #         NaN  ,     Unnamed: 0                              Unnamed: 1  Unnamed: 2  \
# 0          NaN  (16) Other Retail Funding (§.32(a)(5))         NaN
# 1          NaN                                     NaN         NaN
# 2          NaN                                   Field         NaN
# 3          NaN                        Reporting Entity         NaN
# 4          NaN                                Currency         NaN
# 5          NaN                               Converted         NaN
# 6          NaN                                     PID         NaN
# 7          NaN                                 Product         NaN
# 8          NaN                                     SID         NaN
# 9          NaN                             Sub‐Product         NaN
# 10         NaN                         Maturity Amount         NaN
# 11         NaN                         Maturity Bucket         NaN
# 12         NaN                    Forward Start Amount         NaN
# 13         NaN                    Forward Start Bucket         NaN
# 14         NaN                        Collateral Class         NaN
# 15         NaN                        Collateral Value         NaN
#
#                                            Unnamed: 3  Unnamed: 4
# 0                                                 NaN         NaN
# 1                                                 NaN         NaN
# 2                                               Value         NaN
# 3                                            LCR Firm         NaN
# 4                                                   *         NaN
# 5                                                   #         NaN
# 6                                  O.S.1, 2, 7, and 9         NaN
# 7                                         Matches PID         NaN
# 8                                                   #         NaN
# 9   For O.S.7, cannot be Unsettled (Regular Way) o...         NaN
# 10                                                  *         NaN
# 11                                                  #         NaN
# 12                                               NULL         NaN
# 13                                               NULL         NaN
# 14                                                  #         NaN
# 15                                                  #         NaN  ,    Unnamed: 0       Treasury Control  Unnamed: 1                         #  \
# 0         NaN               Internal         NaN                         #
# 1         NaN  Internal Counterparty         NaN                         #
# 2         NaN        Prime Brokerage         NaN                         #
# 3         NaN             Settlement         NaN                         #
# 4         NaN         Rehypothecated         NaN                         #
# 5         NaN                    CID         NaN      Matches Counterparty
# 6         NaN           Counterparty         NaN  Retail or Small Business
#
#    Unnamed: 2
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# 5         NaN
# 6         NaN  ,     Unnamed: 0 (17) Other Retail Funding (§.32(a)(5))  Unnamed: 1  \
# 0          NaN                                    NaN         NaN
# 1          NaN                                  Field         NaN
# 2          NaN                       Reporting Entity         NaN
# 3          NaN                               Currency         NaN
# 4          NaN                              Converted         NaN
# 5          NaN                                    PID         NaN
# 6          NaN                                Product         NaN
# 7          NaN                                    CID         NaN
# 8          NaN                           Counterparty         NaN
# 9          NaN                        Maturity Amount         NaN
# 10         NaN                        Maturity Bucket         NaN
# 11         NaN                       Collateral Class         NaN
# 12         NaN                       Collateral Value         NaN
# 13         NaN                   Forward Start Amount         NaN
# 14         NaN                   Forward Start Bucket         NaN
# 15         NaN                               Internal         NaN
# 16         NaN                  Internal Counterparty         NaN
# 17         NaN                        Prime Brokerage         NaN
#
#                   Unnamed: 2  Unnamed: 3
# 0                        NaN         NaN
# 1                      Value         NaN
# 2                   LCR Firm         NaN
# 3                          *         NaN
# 4                          #         NaN
# 5                     O.W.18         NaN
# 6                Matches PID         NaN
# 7       Matches Counterparty         NaN
# 8   Retail or Small Business         NaN
# 9                          *         NaN
# 10       <= 30 calendar days         NaN
# 11                         #         NaN
# 12                         #         NaN
# 13                      NULL         NaN
# 14                      NULL         NaN
# 15                         #         NaN
# 16                         #         NaN
# 17                         #         NaN  ,     Unnamed: 0                                         Unnamed: 1  Unnamed: 2  \
# 0          NaN  (18) Structured Transaction Outflow Amount (§....         NaN
# 1          NaN  (The total amount for 32(b) is the relevant co...         NaN
# 2          NaN                                            O.O.21)         NaN
# 3          NaN                                                NaN         NaN
# 4          NaN                                              Field         NaN
# 5          NaN                                   Reporting Entity         NaN
# 6          NaN                                           Currency         NaN
# 7          NaN                                          Converted         NaN
# 8          NaN                                                PID         NaN
# 9          NaN                                            Product         NaN
# 10         NaN                                                CID         NaN
# 11         NaN                                       Counterparty         NaN
# 12         NaN                                    Maturity Amount         NaN
# 13         NaN                                    Maturity Bucket         NaN
# 14         NaN                               Forward Start Amount         NaN
# ...
#
#     Unnamed: 1
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN  ,                Unnamed: 0                        (13) O.S. PIDs for item 3.a  \
# 0                   Field                                              Value
# 1        Reporting Entity                                       FR Y‐15 Firm
# 2                Currency                                                  *
# 3               Converted                                                  #
# 4                     PID                            O.S.1, 2, 3, 5, 6, 7, 9
# 5                 Product                                        Matches PID
# 6                     SID                                Matches Sub‐Product
# 7             Sub‐Product  For O.S.7, cannot be Unsettled (Regular Way) o...
# 8         Maturity Amount                                                  *
# 9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
# 10   Forward Start Amount                                               NULL
# 11   Forward Start Bucket                                               NULL
# 12       Collateral Class                                      Level 2B HQLA
# 13       Collateral Value                                                  #
# 14       Treasury Control                                                  #
# 15               Internal                                                  #
# 16  Internal Counterparty                                                  #
# 17        Prime Brokerage                                                  #
# 18             Settlement                                                  #
# 19         Rehypothecated                                                  #
# 20                    CID                               Matches Counterparty
# 21           Counterparty  Non‐Financial Corporate, Sovereign, Central\rB...
#
#     Unnamed: 1
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN  ,                Unnamed: 0                        (14) O.W. PIDs for item 3.a  \
# 0                   Field                                              Value
# 1        Reporting Entity                                       FR Y‐15 Firm
# 2                Currency                                                  *
# 3               Converted                                                  #
# 4                     PID                                      O.W.1‐7, 9‐19
# 5                 Product                                        Matches PID
# 6                     CID                                                  #
# 7            Counterparty                                                  #
# 8         Maturity Amount                                                  *
# 9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
# 10       Collateral Class                                      Level 2B HQLA
# 11       Collateral Value                                                  #
# 12   Forward Start Amount                                               NULL
# 13   Forward Start Bucket                                               NULL
# 14               Internal                                                  #
# 15  Internal Counterparty                                                  #
# 16        Prime Brokerage                                                  #
#
#     Unnamed: 1
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN  ,                    Unnamed: 0  \
# 0                       Field
# 1            Reporting Entity
# 2                    Currency
# 3                   Converted
# 4                         PID
# 5                     Product
# 6                         SID
# 7                 Sub‐Product
# 8             Maturity Amount
# 9             Maturity Bucket
# 10  Effective Maturity Bucket
# 11       Forward Start Amount
# 12       Forward Start Bucket
# 13           Collateral Class
# 14           Collateral Value
# 15               Unencumbered
# 16           Treasury Control
# 17                   Internal
# 18      Internal Counterparty
# 19            Prime Brokerage
# 20                 Settlement
# 21                        CID
# 22               Counterparty
#
#                           (15) O.S. PIDs for item 3.b  Unnamed: 1
# 0                                               Value         NaN
# 1                                        FR Y‐15 Firm         NaN
# 2                                                   *         NaN
# 3                                                   #         NaN
# 4                                               O.S.4         NaN
# 5                                         Matches PID         NaN
# 6   For Collateral Class Level 2B HQLA: 16, 17; Fo...         NaN
# 7                                         Matches SID         NaN
# 8                                                   *         NaN
# 9   Column A: <=30 days\rColumn B:  31 to 90 days\...         NaN
# 10                                                  #         NaN
# 11                                               NULL         NaN
# 12                                               NULL         NaN
# 13                          Level 2B HQLA or Non‐HQLA         NaN
# 14                                                  #         NaN
# 15                                                  #         NaN
# 16                                                  #         NaN
# 17                                                  #         NaN
# 18                                                  #         NaN
# 19                                                  #         NaN
# 20                                                  #         NaN
# 21                                                  #         NaN
# 22                                                  #         NaN  ,                Unnamed: 0                        (16) O.D. PIDs for item 3.c  \
# 0                   Field                                              Value
# 1        Reporting Entity                                       FR Y‐15 Firm
# 2                Currency                                                  *
# 3               Converted                                                  #
# 4                     PID                         O.D.5, 7, 8, 9, 11, 12, 13
# 5                 Product                                        Matches PID
# 6                     CID                               Matches Counterparty
# 7            Counterparty  Bank, Supervised Non‐Bank Financial Entity, De...
# 8         Maturity Amount                                                  *
# 9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
# 10       Collateral Class                                        NULL or Z‐1
# 11       Collateral Value                                               NULL
# 12                Insured                                                  #
# 13                Trigger                                                  #
# 14         Rehypothecated                                                  #
# 15               Internal                                                  #
# 16  Internal Counterparty                                                  #
#
#     Unnamed: 1
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN  ,                Unnamed: 0                        (17) O.W. PIDs for item 3.c  \
# 0                   Field                                              Value
# 1        Reporting Entity                                       FR Y‐15 Firm
# 2                Currency                                                  *
# 3               Converted                                                  #
# 4                     PID                                           O.W.8‐19
# 5                 Product                                        Matches PID
# 6                     CID  For OW.8, 11‐16: #; For O.W.9, 10, 17, 18, 19:...
# 7            Counterparty  For OW.8, 11‐16: #; For O.W.9, 10, 17, 18, 19:...
# 8         Maturity Amount                                                  *
# 9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
# 10       Collateral Class                                               NULL
# 11       Collateral Value                                               NULL
# 12   Forward Start Amount                                               NULL
# 13   Forward Start Bucket                                               NULL
# 14               Internal                                                  #
# 15  Internal Counterparty                                                  #
# 16        Prime Brokerage                                                  #
#
#     Unnamed: 1
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN  ,                Unnamed: 0                          (18) O.D. PIDs for item 4  \
# 0                   Field                                              Value
# 1        Reporting Entity                                       FR Y‐15 Firm
# 2                Currency                                                  *
# 3               Converted                                                  #
# 4                     PID                         O.D.5, 7, 8, 9, 11, 12, 13
# 5                 Product                                        Matches PID
# 6                     CID                               Matches Counterparty
# 7            Counterparty  Non‐Financial Corporate, Sovereign, Central\rB...
# 8         Maturity Amount                                                  *
# 9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
# 10       Collateral Class                                           Non‐HQLA
# 11       Collateral Value                                                  #
# 12                Insured                                                  #
# 13                Trigger                                                  #
# 14         Rehypothecated                                                  #
# 15               Internal                                                  #
# 16  Internal Counterparty                                                  #
#
#     Unnamed: 1
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN  ,                Unnamed: 0                          (19) O.S. PIDs for item 4  \
# 0                   Field                                              Value
# 1        Reporting Entity                                       FR Y‐15 Firm
# 2                Currency                                                  *
# 3               Converted                                                  #
# 4                     PID                              O.S.1, 2, 5, 6, 7 , 9
# 5                 Product                                        Matches PID
# 6                     SID                                Matches Sub‐Product
# 7             Sub‐Product  For O.S.7, cannot be Unsettled (Regular Way) o...
# 8         Maturity Amount                                                  *
# 9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
# 10   Forward Start Amount                                               NULL
# 11   Forward Start Bucket                                               NULL
# 12       Collateral Class                        Not Level 1, 2A, or 2B HQLA
# 13       Collateral Value                                                  #
# 14       Treasury Control                                                  #
# 15               Internal                                                  #
# 16  Internal Counterparty                                                  #
# 17        Prime Brokerage                                                  #
# 18             Settlement                                                  #
# 19         Rehypothecated                                                  #
# 20                    CID                               Matches Counterparty
# 21           Counterparty  Non‐Financial Corporate, Sovereign, Central\rB...
#
#     Unnamed: 1
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN  ,                Unnamed: 0                          (20) O.W. PIDs for item 4  \
# 0                   Field                                              Value
# 1        Reporting Entity                                       FR Y‐15 Firm
# 2                Currency                                                  *
# 3               Converted                                                  #
# 4                     PID                                            O.W.1‐7
# 5                 Product                                        Matches PID
# 6                     CID                                                  #
# 7            Counterparty                                                  #
# 8         Maturity Amount                                                  *
# 9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
# 10       Collateral Class                        Not Level 1, 2A, or 2B HQLA
# 11       Collateral Value                                                  #
# 12   Forward Start Amount                                               NULL
# 13   Forward Start Bucket                                               NULL
# 14               Internal                                                  #
# 15  Internal Counterparty                                                  #
# 16        Prime Brokerage                                                  #
#
#     Unnamed: 1
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN  ]

# %% [markdown]
# Tables [0:14) contain irrelevent data, we will next remove those tables from the data frame and we will rename to df_2052a

# %%
df_2052a = df_tables[15:228]
df_2052a
# Out:
# [    Unnamed: 0 (1) High‐Quality Liquid Assets (Subpart C, §.20‐.22)  \
#  0          NaN                                                NaN
#  1          NaN                                              Field
#  2          NaN                                   Reporting Entity
#  3          NaN                                           Currency
#  4          NaN                                          Converted
#  5          NaN                                                PID
#  6          NaN                                            Product
#  7          NaN                                                SID
#  8          NaN                                        Sub‐Product
#  9          NaN                                       Market Value
#  10         NaN                                     Lendable Value
#  11         NaN                                    Maturity Bucket
#  12         NaN                               Forward Start Amount
#  13         NaN                               Forward Start Bucket
#  14         NaN                                   Collateral Class
#  15         NaN                                   Treasury Control
#
#      Unnamed: 1                     Unnamed: 2  Unnamed: 3
#  0          NaN                            NaN         NaN
#  1          NaN                          Value         NaN
#  2          NaN                       LCR Firm         NaN
#  3          NaN                              *         NaN
#  4          NaN                              #         NaN
#  5          NaN                I.A.1, 2, and 3         NaN
#  6          NaN                    Matches PID         NaN
#  7          NaN            Matches Sub‐Product         NaN
#  8          NaN                 Not Other Cash         NaN
#  9          NaN                              *         NaN
#  10         NaN                              #         NaN
#  11         NaN    Open for I.A.3, # otherwise         NaN
#  12         NaN                           NULL         NaN
#  13         NaN                           NULL         NaN
#  14         NaN  HQLA (except A‐0‐Q for I.A.2)         NaN
#  15         NaN                              Y         NaN  ,
#      Unnamed: 0 (2) Rehypothecatable Collateral (Subpart C, §.20‐.22)  \
#  0          NaN                                                NaN
#  1          NaN                                              Field
#  2          NaN                                   Reporting Entity
#  3          NaN                                           Currency
#  4          NaN                                          Converted
#  5          NaN                                                PID
#  6          NaN                                            Product
#  7          NaN                                                SID
#  8          NaN                                        Sub‐Product
#  9          NaN                                    Maturity Amount
#  10         NaN                                    Maturity Bucket
#  11         NaN                          Effective Maturity Bucket
#  12         NaN                               Forward Start Amount
#  13         NaN                               Forward Start Bucket
#  14         NaN                                   Collateral Class
#  15         NaN                                   Collateral Value
#  16         NaN                                       Unencumbered
#  17         NaN                                   Treasury Control
#  18         NaN                                           Internal
#  19         NaN                              Internal Counterparty
#  20         NaN                                    Prime Brokerage
#  21         NaN                                         Settlement
#  22         NaN                                                CID
#  23         NaN                                       Counterparty
#
#      Unnamed: 1                Unnamed: 2  Unnamed: 3
#  0          NaN                       NaN         NaN
#  1          NaN                     Value         NaN
#  2          NaN                  LCR Firm         NaN
#  3          NaN                         *         NaN
#  4          NaN                         #         NaN
#  5          NaN  I.S.1, 2, 3, 4, 5, and 6         NaN
#  6          NaN               Matches PID         NaN
#  7          NaN                         #         NaN
#  8          NaN                         #         NaN
#  9          NaN                         #         NaN
#  10         NaN                         #         NaN
#  11         NaN                      NULL         NaN
#  12         NaN                      NULL         NaN
#  13         NaN                      NULL         NaN
#  14         NaN       HQLA (except A‐0‐Q)         NaN
#  15         NaN                         *         NaN
#  16         NaN                         Y         NaN
#  17         NaN                         Y         NaN
#  18         NaN                         #         NaN
#  19         NaN                         #         NaN
#  20         NaN                         #         NaN
#  21         NaN                         #         NaN
#  22         NaN                         #         NaN
#  23         NaN                         #         NaN  ,
#      Unnamed: 0 (3) Rehypothecatable Collateral (Subpart C, §.20‐.22)  \
#  0          NaN                                                NaN
#  1          NaN                                              Field
#  2          NaN                                   Reporting Entity
#  3          NaN                                           Currency
#  4          NaN                                          Converted
#  5          NaN                                                PID
#  6          NaN                                            Product
#  7          NaN                                                SID
#  8          NaN                                        Sub‐Product
#  9          NaN                                               SID2
#  10         NaN                                       Sub‐Product2
#  11         NaN                                       Market Value
#  12         NaN                                   Collateral Class
#  13         NaN                                           Internal
#  14         NaN                              Internal Counterparty
#  15         NaN                                    Prime Brokerage
#
#      Unnamed: 1                         Unnamed: 2  Unnamed: 3
#  0          NaN                                NaN         NaN
#  1          NaN                              Value         NaN
#  2          NaN                           LCR Firm         NaN
#  3          NaN                                  *         NaN
#  4          NaN                                  #         NaN
#  5          NaN                        S.I.3 and 6         NaN
#  6          NaN                        Matches PID         NaN
#  7          NaN                Matches Sub‐Product         NaN
#  8          NaN  Unencumbered and Treasury Control         NaN
#  9          NaN                                  #         NaN
#  10         NaN                                  #         NaN
#  11         NaN                                  *         NaN
#  12         NaN                               HQLA         NaN
#  13         NaN                                  #         NaN
#  14         NaN                                  #         NaN
#  15         NaN                                  #         NaN  ,
#      Unnamed: 0                                Unnamed: 1  Unnamed: 2  \
#  0          NaN  (4) Excluded Sub HQLA (§.22(b)(3)and(4))         NaN
#  1          NaN                                     Field         NaN
#  2          NaN                          Reporting Entity         NaN
#  3          NaN                                  Currency         NaN
#  4          NaN                                 Converted         NaN
#  5          NaN                                       PID         NaN
#  6          NaN                                   Product         NaN
#  7          NaN                                       SID         NaN
#  8          NaN                               Sub‐Product         NaN
#  9          NaN                                      SID2         NaN
#  10         NaN                              Sub‐Product2         NaN
#  11         NaN                              Market Value         NaN
#  12         NaN                          Collateral Class         NaN
#  13         NaN                                  Internal         NaN
#  14         NaN                     Internal Counterparty         NaN
#  15         NaN                           Prime Brokerage         NaN
#
#       Unnamed: 3  Unnamed: 4
#  0           NaN         NaN
#  1         Value         NaN
#  2      LCR Firm         NaN
#  3             *         NaN
#  4             #         NaN
#  5        S.I.19         NaN
#  6   Matches PID         NaN
#  7             #         NaN
#  8             #         NaN
#  9             #         NaN
#  10            #         NaN
#  11            *         NaN
#  12         HQLA         NaN
#  13            #         NaN
#  14            #         NaN
#  15            #         NaN  ,
#     Unnamed: 0                                         Unnamed: 1  Unnamed: 2  \
#  0         NaN  (5) Early Hedge Termination Outflows (§.22(a)(3))         NaN
#  1         NaN                                                NaN         NaN
#  2         NaN                                              Field         NaN
#  3         NaN                                   Reporting Entity         NaN
#  4         NaN                                           Currency         NaN
#  5         NaN                                          Converted         NaN
#  6         NaN                                                PID         NaN
#
#    Unnamed: 3  Unnamed: 4
#  0        NaN         NaN
#  1        NaN         NaN
#  2      Value         NaN
#  3   LCR Firm         NaN
#  4          *         NaN
#  5          #         NaN
#  6     S.I.21         NaN  ,
#     Unnamed: 0                Product  Unnamed: 1 Matches PID  Unnamed: 2
#  0         NaN                    SID         NaN           #         NaN
#  1         NaN            Sub‐Product         NaN           #         NaN
#  2         NaN                   SID2         NaN           #         NaN
#  3         NaN           Sub‐Product2         NaN           #         NaN
#  4         NaN           Market Value         NaN           *         NaN
#  5         NaN       Collateral Class         NaN        HQLA         NaN
#  6         NaN               Internal         NaN           #         NaN
#  7         NaN  Internal Counterparty         NaN           #         NaN
#  8         NaN        Prime Brokerage         NaN           #         NaN,
#      Unnamed: 0                          Unnamed: 1  Unnamed: 2   Unnamed: 3  \
#  0          NaN  (6) Excess Collateral (§.22(b)(5))         NaN          NaN
#  1          NaN                                 NaN         NaN          NaN
#  2          NaN                               Field         NaN        Value
#  3          NaN                    Reporting Entity         NaN     LCR Firm
#  4          NaN                            Currency         NaN            *
#  5          NaN                           Converted         NaN            #
#  6          NaN                                 PID         NaN        S.I.9
#  7          NaN                             Product         NaN  Matches PID
#  8          NaN                                 SID         NaN            #
#  9          NaN                         Sub‐Product         NaN            #
#  10         NaN                                SID2         NaN            #
#  11         NaN                        Sub‐Product2         NaN            #
#  12         NaN                        Market Value         NaN            *
#  13         NaN                    Collateral Class         NaN         HQLA
#  14         NaN                            Internal         NaN            #
#  15         NaN               Internal Counterparty         NaN            #
#  16         NaN                     Prime Brokerage         NaN            #
#
#      Unnamed: 4
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8          NaN
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN
#  13         NaN
#  14         NaN
#  15         NaN
#  16         NaN  ,
#      Unnamed: 0 (7) Secured Lending Unwind (Subpart C, §.21)  Unnamed: 1  \
#  0          NaN                                          NaN         NaN
#  1          NaN                                        Field         NaN
#  2          NaN                             Reporting Entity         NaN
#  3          NaN                                     Currency         NaN
#  4          NaN                                    Converted         NaN
#  5          NaN                                          PID         NaN
#  6          NaN                                      Product         NaN
#  7          NaN                                          SID         NaN
#  8          NaN                                  Sub‐Product         NaN
#  9          NaN                              Maturity Amount         NaN
#  10         NaN                              Maturity Bucket         NaN
#  11         NaN                    Effective Maturity Bucket         NaN
#  12         NaN                         Forward Start Amount         NaN
#  13         NaN                         Forward Start Bucket         NaN
#
#                                     Unnamed: 2  Unnamed: 3
#  0                                         NaN         NaN
#  1                                       Value         NaN
#  2                                    LCR Firm         NaN
#  3                                           *         NaN
#  4                                           #         NaN
#  5                       I.S.1, 2, 3, 5, and 6         NaN
#  6                                 Matches PID         NaN
#  7                                           #         NaN
#  8                                           #         NaN
#  9                                           *         NaN
#  10                        <= 30 calendar days         NaN
#  11  NULL or <= 30 calendar days, but not Open         NaN
#  12                                       NULL         NaN
#  13                                       NULL         NaN  ,
#     Unnamed: 0       Collateral Class  Unnamed: 1  \
#  0         NaN       Collateral Value         NaN
#  1         NaN           Unencumbered         NaN
#  2         NaN       Treasury Control         NaN
#  3         NaN               Internal         NaN
#  4         NaN  Internal Counterparty         NaN
#  5         NaN        Prime Brokerage         NaN
#  6         NaN             Settlement         NaN
#  7         NaN                    CID         NaN
#  8         NaN           Counterparty         NaN
#
#                                                  HQLA  Unnamed: 2
#  0                                                  *         NaN
#  1  Y if Effective Maturity Bucket is NULL, otherw...         NaN
#  2                                                  Y         NaN
#  3                                                  #         NaN
#  4                                                  #         NaN
#  5                                                  #         NaN
#  6                                                  #         NaN
#  7                                                  #         NaN
#  8                                                  #         NaN  ,
#      Unnamed: 0                                    Unnamed: 1  Unnamed: 2  \
#  0          NaN  (8) Secured Funding Unwind (Subpart C, §.21)         NaN
#  1          NaN                                           NaN         NaN
#  2          NaN                                         Field         NaN
#  3          NaN                              Reporting Entity         NaN
#  4          NaN                                      Currency         NaN
#  5          NaN                                     Converted         NaN
#  6          NaN                                           PID         NaN
#  7          NaN                                       Product         NaN
#  8          NaN                                           SID         NaN
#  9          NaN                                   Sub‐Product         NaN
#  10         NaN                               Maturity Amount         NaN
#  11         NaN                               Maturity Bucket         NaN
#  12         NaN                          Forward Start Amount         NaN
#  13         NaN                          Forward Start Bucket         NaN
#  14         NaN                              Collateral Class         NaN
#  15         NaN                              Collateral Value         NaN
#  16         NaN                              Treasury Control         NaN
#  17         NaN                                      Internal         NaN
#  18         NaN                         Internal Counterparty         NaN
#  19         NaN                               Prime Brokerage         NaN
#  20         NaN                                    Settlement         NaN
#  21         NaN                                Rehypothecated         NaN
#  22         NaN                                           CID         NaN
#  23         NaN                                  Counterparty         NaN
#
#                                             Unnamed: 3  Unnamed: 4
#  0                                                 NaN         NaN
#  1                                                 NaN         NaN
#  2                                               Value         NaN
#  3                                            LCR Firm         NaN
#  4                                                   *         NaN
#  5                                                   #         NaN
#  6                         O.S.1, 2, 3, 5, 6, 7, and 9         NaN
#  7                                         Matches PID         NaN
#  8                                 Matches Sub‐Product         NaN
#  9   For O.S.7, cannot be Unsettled (Regular Way) o...         NaN
#  10                                                  *         NaN
#  11                                <= 30 calendar days         NaN
#  12                                               NULL         NaN
#  13                                               NULL         NaN
#  14                                               HQLA         NaN
#  15                                                  *         NaN
#  16                                                  Y         NaN
#  17                                                  #         NaN
#  18                                                  #         NaN
#  19                                                  #         NaN
#  20                                                  #         NaN
#  21                                                  #         NaN
#  22                                                  #         NaN
#  23                                                  #         NaN  ,
#     Unnamed: 0                                   Unnamed: 1  Unnamed: 2  \
#  0         NaN  (9) Asset Exchange Unwind (Subpart C, §.21)         NaN
#  1         NaN                                          NaN         NaN
#  2         NaN                                        Field         NaN
#  3         NaN                             Reporting Entity         NaN
#  4         NaN                                     Currency         NaN
#  5         NaN                                    Converted         NaN
#  6         NaN                                          PID         NaN
#  7         NaN                                      Product         NaN
#
#    Unnamed: 3  Unnamed: 4
#  0        NaN         NaN
#  1        NaN         NaN
#  2      Value         NaN
#  3   LCR Firm         NaN
#  4          *         NaN
#  5          #         NaN
#  6      I.S.4         NaN
#  7          #         NaN  ,
#      Unnamed: 0                        SID  Unnamed: 1  \
#  0          NaN                Sub‐Product         NaN
#  1          NaN            Maturity Amount         NaN
#  2          NaN            Maturity Bucket         NaN
#  3          NaN  Effective Maturity Bucket         NaN
#  4          NaN       Forward Start Amount         NaN
#  5          NaN       Forward Start Bucket         NaN
#  6          NaN           Collateral Class         NaN
#  7          NaN           Collateral Value         NaN
#  8          NaN               Unencumbered         NaN
#  9          NaN           Treasury Control         NaN
#  10         NaN                   Internal         NaN
#  11         NaN      Internal Counterparty         NaN
#  12         NaN            Prime Brokerage         NaN
#  13         NaN                 Settlement         NaN
#  14         NaN                        CID         NaN
#  15         NaN               Counterparty         NaN
#
#                                    Matches Sub‐Product  Unnamed: 2
#  0      Level 1 HQLA, Level 2A HQLA, and Level 2B HQLA         NaN
#  1                                                   *         NaN
#  2                                 <= 30 calendar days         NaN
#  3               NULL or <= 30 calendar days, not Open         NaN
#  4                                                NULL         NaN
#  5                                                NULL         NaN
#  6                                                HQLA         NaN
#  7                                                   *         NaN
#  8   Y if Effective Maturity Bucket is NULL, otherw...         NaN
#  9                                                   Y         NaN
#  10                                                  #         NaN
#  11                                                  #         NaN
#  12                                                  #         NaN
#  13                                                  #         NaN
#  14                                                  #         NaN
#  15                                                  #         NaN  ,
#      Unnamed: 0 (10) Stable Retail Deposits (§.32(a)(1))  Unnamed: 1  \
#  0          NaN                                      NaN         NaN
#  1          NaN                                    Field         NaN
#  2          NaN                         Reporting Entity         NaN
#  3          NaN                                 Currency         NaN
#  4          NaN                                Converted         NaN
#  5          NaN                                      PID         NaN
#  6          NaN                                  Product         NaN
#  7          NaN                                      CID         NaN
#  8          NaN                             Counterparty         NaN
#  9          NaN                          Maturity Amount         NaN
#  10         NaN                          Maturity Bucket         NaN
#  11         NaN                         Collateral Class         NaN
#  12         NaN                         Collateral Value         NaN
#  13         NaN                                  Insured         NaN
#  14         NaN                                  Trigger         NaN
#  15         NaN                           Rehypothecated         NaN
#  16         NaN                                 Internal         NaN
#  17         NaN                    Internal Counterparty         NaN
#
#                    Unnamed: 2  Unnamed: 3
#  0                        NaN         NaN
#  1                      Value         NaN
#  2                   LCR Firm         NaN
#  3                          *         NaN
#  4                          #         NaN
#  5                O.D.1 and 2         NaN
#  6                Matches PID         NaN
#  7       Matches Counterparty         NaN
#  8   Retail or Small Business         NaN
#  9                          *         NaN
#  10                         #         NaN
#  11                         #         NaN
#  12                         #         NaN
#  13                      FDIC         NaN
#  14                         #         NaN
#  15                         #         NaN
#  16                         #         NaN
#  17                         #         NaN  ,
#      Unnamed: 0                               Unnamed: 1  Unnamed: 2  \
#  0          NaN  (11) Other Retail Deposits (§.32(a)(2))         NaN
#  1          NaN                                      NaN         NaN
#  2          NaN                                    Field         NaN
#  3          NaN                         Reporting Entity         NaN
#  4          NaN                                 Currency         NaN
#  5          NaN                                Converted         NaN
#  6          NaN                                      PID         NaN
#  7          NaN                                  Product         NaN
#  8          NaN                                      CID         NaN
#  9          NaN                             Counterparty         NaN
#  10         NaN                          Maturity Amount         NaN
#  11         NaN                          Maturity Bucket         NaN
#  12         NaN                         Collateral Class         NaN
#  13         NaN                         Collateral Value         NaN
#  14         NaN                                  Insured         NaN
#  15         NaN                                  Trigger         NaN
#  16         NaN                           Rehypothecated         NaN
#  17         NaN                                 Internal         NaN
#  18         NaN                    Internal Counterparty         NaN
#
#                                         Unnamed: 3  Unnamed: 4
#  0                                             NaN         NaN
#  1                                             NaN         NaN
#  2                                           Value         NaN
#  3                                        LCR Firm         NaN
#  4                                               *         NaN
#  5                                               #         NaN
#  6                                 O.D.1, 2, and 3         NaN
#  7                                     Matches PID         NaN
#  8                            Matches Counterparty         NaN
#  9                        Retail or Small Business         NaN
#  10                                              *         NaN
#  11                                              #         NaN
#  12                                              #         NaN
#  13                                              #         NaN
#  14  Not FDIC for PID = 1 and 2, and # for PID = 3         NaN
#  15                                              #         NaN
#  16                                              #         NaN
#  17                                              #         NaN
#  18                                              #         NaN  ,
#     Unnamed: 0 (12) Insured Placed Retail Deposits (§.32(a)(3))  Unnamed: 1  \
#  0         NaN                                              NaN         NaN
#  1         NaN                                            Field         NaN
#  2         NaN                                 Reporting Entity         NaN
#  3         NaN                                         Currency         NaN
#
#    Unnamed: 2  Unnamed: 3
#  0        NaN         NaN
#  1      Value         NaN
#  2   LCR Firm         NaN
#  3          *         NaN  ,
#      Unnamed: 0              Converted  Unnamed: 1                         #  \
#  0          NaN                    PID         NaN                    O.D.12
#  1          NaN                Product         NaN               Matches PID
#  2          NaN                    CID         NaN      Matches Counterparty
#  3          NaN           Counterparty         NaN  Retail or Small Business
#  4          NaN        Maturity Amount         NaN                         *
#  5          NaN        Maturity Bucket         NaN                         #
#  6          NaN       Collateral Class         NaN                         #
#  7          NaN       Collateral Value         NaN                         #
#  8          NaN                Insured         NaN                      FDIC
#  9          NaN                Trigger         NaN                         #
#  10         NaN         Rehypothecated         NaN                         #
#  11         NaN               Internal         NaN                         #
#  12         NaN  Internal Counterparty         NaN                         #
#
#      Unnamed: 2
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8          NaN
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN  ,
#      Unnamed: 0 (13) Non‐Insured Placed Retail Deposits (§.32(a)(4))  \
#  0          NaN                                                NaN
#  1          NaN                                              Field
#  2          NaN                                   Reporting Entity
#  3          NaN                                           Currency
#  4          NaN                                          Converted
#  5          NaN                                                PID
#  6          NaN                                            Product
#  7          NaN                                                CID
#  8          NaN                                       Counterparty
#  9          NaN                                    Maturity Amount
#  10         NaN                                    Maturity Bucket
#  11         NaN                                   Collateral Class
#  12         NaN                                   Collateral Value
#  13         NaN                                            Insured
#  14         NaN                                            Trigger
#  15         NaN                                     Rehypothecated
#  16         NaN                                           Internal
#  17         NaN                              Internal Counterparty
#
#      Unnamed: 1                Unnamed: 2  Unnamed: 3
#  0          NaN                       NaN         NaN
#  1          NaN                     Value         NaN
#  2          NaN                  LCR Firm         NaN
#  3          NaN                         *         NaN
#  4          NaN                         #         NaN
#  5          NaN                    O.D.12         NaN
#  6          NaN               Matches PID         NaN
#  7          NaN      Matches Counterparty         NaN
#  8          NaN  Retail or Small Business         NaN
#  9          NaN                         *         NaN
#  10         NaN                         #         NaN
#  11         NaN                         #         NaN
#  12         NaN                         #         NaN
#  13         NaN                  Not FDIC         NaN
#  14         NaN                         #         NaN
#  15         NaN                         #         NaN
#  16         NaN                         #         NaN
#  17         NaN                         #         NaN  ,
#     Unnamed: 0                              Unnamed: 1  Unnamed: 2  \
#  0         NaN  (14) Other Retail Funding (§.32(a)(5))         NaN
#  1         NaN                                   Field         NaN
#  2         NaN                        Reporting Entity         NaN
#  3         NaN                                Currency         NaN
#  4         NaN                               Converted         NaN
#  5         NaN                                     PID         NaN
#  6         NaN                                 Product         NaN
#  7         NaN                                     CID         NaN
#  8         NaN                            Counterparty         NaN
#  9         NaN                         Maturity Amount         NaN
#
#                   Unnamed: 3  Unnamed: 4
#  0                       NaN         NaN
#  1                     Value         NaN
#  2                  LCR Firm         NaN
#  3                         *         NaN
#  4                         #         NaN
#  5                    O.D.13         NaN
#  6               Matches PID         NaN
#  7      Matches Counterparty         NaN
#  8  Retail or Small Business         NaN
#  9                         *         NaN  ,
#     Unnamed: 0        Maturity Bucket  Unnamed: 1     #  Unnamed: 2
#  0         NaN       Collateral Class         NaN     #         NaN
#  1         NaN       Collateral Value         NaN     #         NaN
#  2         NaN                Insured         NaN     #         NaN
#  3         NaN                Trigger         NaN     #         NaN
#  4         NaN         Rehypothecated         NaN  NULL         NaN
#  5         NaN               Internal         NaN     #         NaN
#  6         NaN  Internal Counterparty         NaN     #         NaN,
#      Unnamed: 0 (15) Other Retail Funding (§.32(a)(5))  Unnamed: 1  \
#  0          NaN                                    NaN         NaN
#  1          NaN                                  Field         NaN
#  2          NaN                       Reporting Entity         NaN
#  3          NaN                               Currency         NaN
#  4          NaN                              Converted         NaN
#  5          NaN                                    PID         NaN
#  6          NaN                                Product         NaN
#  7          NaN                                    CID         NaN
#  8          NaN                           Counterparty         NaN
#  9          NaN                        Maturity Amount         NaN
#  10         NaN                        Maturity Bucket         NaN
#  11         NaN                   Forward Start Amount         NaN
#  12         NaN                   Forward Start Bucket         NaN
#  13         NaN                       Collateral Class         NaN
#  14         NaN                       Collateral Value         NaN
#  15         NaN                               Internal         NaN
#  16         NaN                  Internal Counterparty         NaN
#  17         NaN                        Prime Brokerage         NaN
#
#                    Unnamed: 2  Unnamed: 3
#  0                        NaN         NaN
#  1                      Value         NaN
#  2                   LCR Firm         NaN
#  3                          *         NaN
#  4                          #         NaN
#  5                     O.O.22         NaN
#  6                Matches PID         NaN
#  7       Matches Counterparty         NaN
#  8   Retail or Small Business         NaN
#  9                          *         NaN
#  10                         #         NaN
#  11                      NULL         NaN
#  12                      NULL         NaN
#  13                         #         NaN
#  14                         #         NaN
#  15                         #         NaN
#  16                         #         NaN
#  17                         #         NaN  ,
#      Unnamed: 0                              Unnamed: 1  Unnamed: 2  \
#  0          NaN  (16) Other Retail Funding (§.32(a)(5))         NaN
#  1          NaN                                     NaN         NaN
#  2          NaN                                   Field         NaN
#  3          NaN                        Reporting Entity         NaN
#  4          NaN                                Currency         NaN
#  5          NaN                               Converted         NaN
#  6          NaN                                     PID         NaN
#  7          NaN                                 Product         NaN
#  8          NaN                                     SID         NaN
#  9          NaN                             Sub‐Product         NaN
#  10         NaN                         Maturity Amount         NaN
#  11         NaN                         Maturity Bucket         NaN
#  12         NaN                    Forward Start Amount         NaN
#  13         NaN                    Forward Start Bucket         NaN
#  14         NaN                        Collateral Class         NaN
#  15         NaN                        Collateral Value         NaN
#
#                                             Unnamed: 3  Unnamed: 4
#  0                                                 NaN         NaN
#  1                                                 NaN         NaN
#  2                                               Value         NaN
#  3                                            LCR Firm         NaN
#  4                                                   *         NaN
#  5                                                   #         NaN
#  6                                  O.S.1, 2, 7, and 9         NaN
#  7                                         Matches PID         NaN
#  8                                                   #         NaN
#  9   For O.S.7, cannot be Unsettled (Regular Way) o...         NaN
#  10                                                  *         NaN
#  11                                                  #         NaN
#  12                                               NULL         NaN
#  13                                               NULL         NaN
#  14                                                  #         NaN
#  15                                                  #         NaN  ,
#     Unnamed: 0       Treasury Control  Unnamed: 1                         #  \
#  0         NaN               Internal         NaN                         #
#  1         NaN  Internal Counterparty         NaN                         #
#  2         NaN        Prime Brokerage         NaN                         #
#  3         NaN             Settlement         NaN                         #
#  4         NaN         Rehypothecated         NaN                         #
#  5         NaN                    CID         NaN      Matches Counterparty
#  6         NaN           Counterparty         NaN  Retail or Small Business
#
#     Unnamed: 2
#  0         NaN
#  1         NaN
#  2         NaN
#  3         NaN
#  4         NaN
#  5         NaN
#  6         NaN  ,
#      Unnamed: 0 (17) Other Retail Funding (§.32(a)(5))  Unnamed: 1  \
#  0          NaN                                    NaN         NaN
#  1          NaN                                  Field         NaN
#  2          NaN                       Reporting Entity         NaN
#  3          NaN                               Currency         NaN
#  4          NaN                              Converted         NaN
#  5          NaN                                    PID         NaN
#  6          NaN                                Product         NaN
#  7          NaN                                    CID         NaN
#  8          NaN                           Counterparty         NaN
#  9          NaN                        Maturity Amount         NaN
#  10         NaN                        Maturity Bucket         NaN
#  11         NaN                       Collateral Class         NaN
#  12         NaN                       Collateral Value         NaN
#  13         NaN                   Forward Start Amount         NaN
#  14         NaN                   Forward Start Bucket         NaN
#  15         NaN                               Internal         NaN
#  16         NaN                  Internal Counterparty         NaN
#  17         NaN                        Prime Brokerage         NaN
#
#                    Unnamed: 2  Unnamed: 3
#  0                        NaN         NaN
#  1                      Value         NaN
#  2                   LCR Firm         NaN
#  3                          *         NaN
#  4                          #         NaN
#  5                     O.W.18         NaN
#  6                Matches PID         NaN
#  7       Matches Counterparty         NaN
#  8   Retail or Small Business         NaN
#  9                          *         NaN
#  10       <= 30 calendar days         NaN
#  11                         #         NaN
#  12                         #         NaN
#  13                      NULL         NaN
#  14                      NULL         NaN
#  15                         #         NaN
#  16                         #         NaN
#  17                         #         NaN  ,
#      Unnamed: 0                                         Unnamed: 1  Unnamed: 2  \
#  0          NaN  (18) Structured Transaction Outflow Amount (§....         NaN
#  1          NaN  (The total amount for 32(b) is the relevant co...         NaN
#  2          NaN                                            O.O.21)         NaN
#  3          NaN                                                NaN         NaN
#  4          NaN                                              Field         NaN
#  5          NaN                                   Reporting Entity         NaN
#  6          NaN                                           Currency         NaN
#  7          NaN                                          Converted         NaN
#  8          NaN                                                PID         NaN
#  9          NaN                                            Product         NaN
#  10         NaN                                                CID         NaN
#  11         NaN                                       Counterparty         NaN
#  12         NaN                                    Maturity Amount         NaN
#  13         NaN                                    Maturity Bucket         NaN
#  14         NaN                               Forward Start Amount         NaN
#  15         NaN                               Forward Start Bucket         NaN
#  16         NaN                                   Collateral Class         NaN
#
#                                Unnamed: 3  Unnamed: 4
#  0                                    NaN         NaN
#  1                                    NaN         NaN
#  2                                    NaN         NaN
#  3                                    NaN         NaN
#  4                                  Value         NaN
#  5                               LCR Firm         NaN
#  6                                      *         NaN
#  7                                      #         NaN
#  8   O.O.21 (adds the incremental amount)         NaN
#  9                            Matches PID         NaN
#  10                                     #         NaN
#  11                                     #         NaN
#  12                                     *         NaN
#  13                   <= 30 calendar days         NaN
#  14                                     #         NaN
#  15                                     #         NaN
#  16                                     #         NaN  ,
#     Unnamed: 0       Collateral Value  Unnamed: 1  #  Unnamed: 2
#  0         NaN               Internal         NaN  #         NaN
#  1         NaN  Internal Counterparty         NaN  #         NaN
#  2         NaN        Prime Brokerage         NaN  #         NaN,
#      Unnamed: 0 (19) Net Derivatives Cash Outflow Amount (§.32(c))  Unnamed: 1  \
#  0          NaN                                                NaN         NaN
#  1          NaN                                              Field         NaN
#  2          NaN                                   Reporting Entity         NaN
#  3          NaN                                           Currency         NaN
#  4          NaN                                          Converted         NaN
#  5          NaN                                                PID         NaN
#  6          NaN                                            Product         NaN
#  7          NaN                                                CID         NaN
#  8          NaN                                       Counterparty         NaN
#  9          NaN                                    Maturity Amount         NaN
#  10         NaN                                    Maturity Bucket         NaN
#  11         NaN                               Forward Start Amount         NaN
#  12         NaN                               Forward Start Bucket         NaN
#  13         NaN                                   Collateral Class         NaN
#  14         NaN                                   Collateral Value         NaN
#  15         NaN                                           Internal         NaN
#  16         NaN                              Internal Counterparty         NaN
#  17         NaN                                    Prime Brokerage         NaN
#
#       Unnamed: 2  Unnamed: 3
#  0           NaN         NaN
#  1         Value         NaN
#  2      LCR Firm         NaN
#  3             *         NaN
#  4             #         NaN
#  5        O.O.20         NaN
#  6   Matches PID         NaN
#  7             #         NaN
#  8             #         NaN
#  9             *         NaN
#  10            #         NaN
#  11            #         NaN
#  12            #         NaN
#  13            #         NaN
#  14            #         NaN
#  15            #         NaN
#  16            #         NaN
#  17            #         NaN  ,
#      Unnamed: 0 (20) Mortgage Commitment Outflow Amount (§.32(d))  Unnamed: 1  \
#  0          NaN                                               NaN         NaN
#  1          NaN                                             Field         NaN
#  2          NaN                                  Reporting Entity         NaN
#  3          NaN                                          Currency         NaN
#  4          NaN                                         Converted         NaN
#  5          NaN                                               PID         NaN
#  6          NaN                                           Product         NaN
#  7          NaN                                               CID         NaN
#  8          NaN                                      Counterparty         NaN
#  9          NaN                                   Maturity Amount         NaN
#  10         NaN                                   Maturity Bucket         NaN
#  11         NaN                              Forward Start Amount         NaN
#  12         NaN                              Forward Start Bucket         NaN
#  13         NaN                                  Collateral Class         NaN
#  14         NaN                                  Collateral Value         NaN
#  15         NaN                                          Internal         NaN
#  16         NaN                             Internal Counterparty         NaN
# ...
#  15         NaN
#  16         NaN  ,
#                 Unnamed: 0                        (13) O.S. PIDs for item 3.a  \
#  0                   Field                                              Value
#  1        Reporting Entity                                       FR Y‐15 Firm
#  2                Currency                                                  *
#  3               Converted                                                  #
#  4                     PID                            O.S.1, 2, 3, 5, 6, 7, 9
#  5                 Product                                        Matches PID
#  6                     SID                                Matches Sub‐Product
#  7             Sub‐Product  For O.S.7, cannot be Unsettled (Regular Way) o...
#  8         Maturity Amount                                                  *
#  9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
#  10   Forward Start Amount                                               NULL
#  11   Forward Start Bucket                                               NULL
#  12       Collateral Class                                      Level 2B HQLA
#  13       Collateral Value                                                  #
#  14       Treasury Control                                                  #
#  15               Internal                                                  #
#  16  Internal Counterparty                                                  #
#  17        Prime Brokerage                                                  #
#  18             Settlement                                                  #
#  19         Rehypothecated                                                  #
#  20                    CID                               Matches Counterparty
#  21           Counterparty  Non‐Financial Corporate, Sovereign, Central\rB...
#
#      Unnamed: 1
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8          NaN
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN
#  13         NaN
#  14         NaN
#  15         NaN
#  16         NaN
#  17         NaN
#  18         NaN
#  19         NaN
#  20         NaN
#  21         NaN  ,
#                 Unnamed: 0                        (14) O.W. PIDs for item 3.a  \
#  0                   Field                                              Value
#  1        Reporting Entity                                       FR Y‐15 Firm
#  2                Currency                                                  *
#  3               Converted                                                  #
#  4                     PID                                      O.W.1‐7, 9‐19
#  5                 Product                                        Matches PID
#  6                     CID                                                  #
#  7            Counterparty                                                  #
#  8         Maturity Amount                                                  *
#  9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
#  10       Collateral Class                                      Level 2B HQLA
#  11       Collateral Value                                                  #
#  12   Forward Start Amount                                               NULL
#  13   Forward Start Bucket                                               NULL
#  14               Internal                                                  #
#  15  Internal Counterparty                                                  #
#  16        Prime Brokerage                                                  #
#
#      Unnamed: 1
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8          NaN
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN
#  13         NaN
#  14         NaN
#  15         NaN
#  16         NaN  ,
#                     Unnamed: 0  \
#  0                       Field
#  1            Reporting Entity
#  2                    Currency
#  3                   Converted
#  4                         PID
#  5                     Product
#  6                         SID
#  7                 Sub‐Product
#  8             Maturity Amount
#  9             Maturity Bucket
#  10  Effective Maturity Bucket
#  11       Forward Start Amount
#  12       Forward Start Bucket
#  13           Collateral Class
#  14           Collateral Value
#  15               Unencumbered
#  16           Treasury Control
#  17                   Internal
#  18      Internal Counterparty
#  19            Prime Brokerage
#  20                 Settlement
#  21                        CID
#  22               Counterparty
#
#                            (15) O.S. PIDs for item 3.b  Unnamed: 1
#  0                                               Value         NaN
#  1                                        FR Y‐15 Firm         NaN
#  2                                                   *         NaN
#  3                                                   #         NaN
#  4                                               O.S.4         NaN
#  5                                         Matches PID         NaN
#  6   For Collateral Class Level 2B HQLA: 16, 17; Fo...         NaN
#  7                                         Matches SID         NaN
#  8                                                   *         NaN
#  9   Column A: <=30 days\rColumn B:  31 to 90 days\...         NaN
#  10                                                  #         NaN
#  11                                               NULL         NaN
#  12                                               NULL         NaN
#  13                          Level 2B HQLA or Non‐HQLA         NaN
#  14                                                  #         NaN
#  15                                                  #         NaN
#  16                                                  #         NaN
#  17                                                  #         NaN
#  18                                                  #         NaN
#  19                                                  #         NaN
#  20                                                  #         NaN
#  21                                                  #         NaN
#  22                                                  #         NaN  ,
#                 Unnamed: 0                        (16) O.D. PIDs for item 3.c  \
#  0                   Field                                              Value
#  1        Reporting Entity                                       FR Y‐15 Firm
#  2                Currency                                                  *
#  3               Converted                                                  #
#  4                     PID                         O.D.5, 7, 8, 9, 11, 12, 13
#  5                 Product                                        Matches PID
#  6                     CID                               Matches Counterparty
#  7            Counterparty  Bank, Supervised Non‐Bank Financial Entity, De...
#  8         Maturity Amount                                                  *
#  9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
#  10       Collateral Class                                        NULL or Z‐1
#  11       Collateral Value                                               NULL
#  12                Insured                                                  #
#  13                Trigger                                                  #
#  14         Rehypothecated                                                  #
#  15               Internal                                                  #
#  16  Internal Counterparty                                                  #
#
#      Unnamed: 1
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8          NaN
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN
#  13         NaN
#  14         NaN
#  15         NaN
#  16         NaN  ,
#                 Unnamed: 0                        (17) O.W. PIDs for item 3.c  \
#  0                   Field                                              Value
#  1        Reporting Entity                                       FR Y‐15 Firm
#  2                Currency                                                  *
#  3               Converted                                                  #
#  4                     PID                                           O.W.8‐19
#  5                 Product                                        Matches PID
#  6                     CID  For OW.8, 11‐16: #; For O.W.9, 10, 17, 18, 19:...
#  7            Counterparty  For OW.8, 11‐16: #; For O.W.9, 10, 17, 18, 19:...
#  8         Maturity Amount                                                  *
#  9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
#  10       Collateral Class                                               NULL
#  11       Collateral Value                                               NULL
#  12   Forward Start Amount                                               NULL
#  13   Forward Start Bucket                                               NULL
#  14               Internal                                                  #
#  15  Internal Counterparty                                                  #
#  16        Prime Brokerage                                                  #
#
#      Unnamed: 1
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8          NaN
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN
#  13         NaN
#  14         NaN
#  15         NaN
#  16         NaN  ,
#                 Unnamed: 0                          (18) O.D. PIDs for item 4  \
#  0                   Field                                              Value
#  1        Reporting Entity                                       FR Y‐15 Firm
#  2                Currency                                                  *
#  3               Converted                                                  #
#  4                     PID                         O.D.5, 7, 8, 9, 11, 12, 13
#  5                 Product                                        Matches PID
#  6                     CID                               Matches Counterparty
#  7            Counterparty  Non‐Financial Corporate, Sovereign, Central\rB...
#  8         Maturity Amount                                                  *
#  9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
#  10       Collateral Class                                           Non‐HQLA
#  11       Collateral Value                                                  #
#  12                Insured                                                  #
#  13                Trigger                                                  #
#  14         Rehypothecated                                                  #
#  15               Internal                                                  #
#  16  Internal Counterparty                                                  #
#
#      Unnamed: 1
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8          NaN
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN
#  13         NaN
#  14         NaN
#  15         NaN
#  16         NaN  ,
#                 Unnamed: 0                          (19) O.S. PIDs for item 4  \
#  0                   Field                                              Value
#  1        Reporting Entity                                       FR Y‐15 Firm
#  2                Currency                                                  *
#  3               Converted                                                  #
#  4                     PID                              O.S.1, 2, 5, 6, 7 , 9
#  5                 Product                                        Matches PID
#  6                     SID                                Matches Sub‐Product
#  7             Sub‐Product  For O.S.7, cannot be Unsettled (Regular Way) o...
#  8         Maturity Amount                                                  *
#  9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
#  10   Forward Start Amount                                               NULL
#  11   Forward Start Bucket                                               NULL
#  12       Collateral Class                        Not Level 1, 2A, or 2B HQLA
#  13       Collateral Value                                                  #
#  14       Treasury Control                                                  #
#  15               Internal                                                  #
#  16  Internal Counterparty                                                  #
#  17        Prime Brokerage                                                  #
#  18             Settlement                                                  #
#  19         Rehypothecated                                                  #
#  20                    CID                               Matches Counterparty
#  21           Counterparty  Non‐Financial Corporate, Sovereign, Central\rB...
#
#      Unnamed: 1
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8          NaN
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN
#  13         NaN
#  14         NaN
#  15         NaN
#  16         NaN
#  17         NaN
#  18         NaN
#  19         NaN
#  20         NaN
#  21         NaN  ,
#                 Unnamed: 0                          (20) O.W. PIDs for item 4  \
#  0                   Field                                              Value
#  1        Reporting Entity                                       FR Y‐15 Firm
#  2                Currency                                                  *
#  3               Converted                                                  #
#  4                     PID                                            O.W.1‐7
#  5                 Product                                        Matches PID
#  6                     CID                                                  #
#  7            Counterparty                                                  #
#  8         Maturity Amount                                                  *
#  9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
#  10       Collateral Class                        Not Level 1, 2A, or 2B HQLA
#  11       Collateral Value                                                  #
#  12   Forward Start Amount                                               NULL
#  13   Forward Start Bucket                                               NULL
#  14               Internal                                                  #
#  15  Internal Counterparty                                                  #
#  16        Prime Brokerage                                                  #
#
#      Unnamed: 1
#  0          NaN
#  1          NaN
#  2          NaN
#  3          NaN
#  4          NaN
#  5          NaN
#  6          NaN
#  7          NaN
#  8          NaN
#  9          NaN
#  10         NaN
#  11         NaN
#  12         NaN
#  13         NaN
#  14         NaN
#  15         NaN
#  16         NaN  ]

# %% [markdown]
# Below we're referencing the first and last tables that we're wanting to leverage 2052a rules from, which include 0 as the first and 212 as the last:

# %%
df_2052a[0]
# Out:
#     Unnamed: 0 (1) High‐Quality Liquid Assets (Subpart C, §.20‐.22)  \
# 0          NaN                                                NaN
# 1          NaN                                              Field
# 2          NaN                                   Reporting Entity
# 3          NaN                                           Currency
# 4          NaN                                          Converted
# 5          NaN                                                PID
# 6          NaN                                            Product
# 7          NaN                                                SID
# 8          NaN                                        Sub‐Product
# 9          NaN                                       Market Value
# 10         NaN                                     Lendable Value
# 11         NaN                                    Maturity Bucket
# 12         NaN                               Forward Start Amount
# 13         NaN                               Forward Start Bucket
# 14         NaN                                   Collateral Class
# 15         NaN                                   Treasury Control
#
#     Unnamed: 1                     Unnamed: 2  Unnamed: 3
# 0          NaN                            NaN         NaN
# 1          NaN                          Value         NaN
# 2          NaN                       LCR Firm         NaN
# 3          NaN                              *         NaN
# 4          NaN                              #         NaN
# 5          NaN                I.A.1, 2, and 3         NaN
# 6          NaN                    Matches PID         NaN
# 7          NaN            Matches Sub‐Product         NaN
# 8          NaN                 Not Other Cash         NaN
# 9          NaN                              *         NaN
# 10         NaN                              #         NaN
# 11         NaN    Open for I.A.3, # otherwise         NaN
# 12         NaN                           NULL         NaN
# 13         NaN                           NULL         NaN
# 14         NaN  HQLA (except A‐0‐Q for I.A.2)         NaN
# 15         NaN                              Y         NaN

# %%
df_2052a[212]
# Out:
#                Unnamed: 0                          (20) O.W. PIDs for item 4  \
# 0                   Field                                              Value
# 1        Reporting Entity                                       FR Y‐15 Firm
# 2                Currency                                                  *
# 3               Converted                                                  #
# 4                     PID                                            O.W.1‐7
# 5                 Product                                        Matches PID
# 6                     CID                                                  #
# 7            Counterparty                                                  #
# 8         Maturity Amount                                                  *
# 9         Maturity Bucket  Column A: <=30 days\rColumn B:  31 to 90 days\...
# 10       Collateral Class                        Not Level 1, 2A, or 2B HQLA
# 11       Collateral Value                                                  #
# 12   Forward Start Amount                                               NULL
# 13   Forward Start Bucket                                               NULL
# 14               Internal                                                  #
# 15  Internal Counterparty                                                  #
# 16        Prime Brokerage                                                  #
#
#     Unnamed: 1
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN

# %% [markdown]
# We can see that the last table with rules that we want to scrape 212; starting with HQLA rules on 15. The next step is to understand the data so that I can write a function to clean the table data and put it into a useable tabular format

# %%
test_rule = df_2052a[0]
test_rule
# Out:
#     Unnamed: 0 (1) High‐Quality Liquid Assets (Subpart C, §.20‐.22)  \
# 0          NaN                                                NaN
# 1          NaN                                              Field
# 2          NaN                                   Reporting Entity
# 3          NaN                                           Currency
# 4          NaN                                          Converted
# 5          NaN                                                PID
# 6          NaN                                            Product
# 7          NaN                                                SID
# 8          NaN                                        Sub‐Product
# 9          NaN                                       Market Value
# 10         NaN                                     Lendable Value
# 11         NaN                                    Maturity Bucket
# 12         NaN                               Forward Start Amount
# 13         NaN                               Forward Start Bucket
# 14         NaN                                   Collateral Class
# 15         NaN                                   Treasury Control
#
#     Unnamed: 1                     Unnamed: 2  Unnamed: 3
# 0          NaN                            NaN         NaN
# 1          NaN                          Value         NaN
# 2          NaN                       LCR Firm         NaN
# 3          NaN                              *         NaN
# 4          NaN                              #         NaN
# 5          NaN                I.A.1, 2, and 3         NaN
# 6          NaN                    Matches PID         NaN
# 7          NaN            Matches Sub‐Product         NaN
# 8          NaN                 Not Other Cash         NaN
# 9          NaN                              *         NaN
# 10         NaN                              #         NaN
# 11         NaN    Open for I.A.3, # otherwise         NaN
# 12         NaN                           NULL         NaN
# 13         NaN                           NULL         NaN
# 14         NaN  HQLA (except A‐0‐Q for I.A.2)         NaN
# 15         NaN                              Y         NaN

# %% [markdown]
# By calling shape pandas will return a tuple describing the dimensionality of our first data frame that we care about

# %%
test_rule.shape
# Out:
# (16, 5)

# %%
test_rule.describe
# Out:
# <bound method NDFrame.describe of     Unnamed: 0 (1) High‐Quality Liquid Assets (Subpart C, §.20‐.22)  \
# 0          NaN                                                NaN
# 1          NaN                                              Field
# 2          NaN                                   Reporting Entity
# 3          NaN                                           Currency
# 4          NaN                                          Converted
# 5          NaN                                                PID
# 6          NaN                                            Product
# 7          NaN                                                SID
# 8          NaN                                        Sub‐Product
# 9          NaN                                       Market Value
# 10         NaN                                     Lendable Value
# 11         NaN                                    Maturity Bucket
# 12         NaN                               Forward Start Amount
# 13         NaN                               Forward Start Bucket
# 14         NaN                                   Collateral Class
# 15         NaN                                   Treasury Control
#
#     Unnamed: 1                     Unnamed: 2  Unnamed: 3
# 0          NaN                            NaN         NaN
# 1          NaN                          Value         NaN
# 2          NaN                       LCR Firm         NaN
# 3          NaN                              *         NaN
# 4          NaN                              #         NaN
# 5          NaN                I.A.1, 2, and 3         NaN
# 6          NaN                    Matches PID         NaN
# 7          NaN            Matches Sub‐Product         NaN
# 8          NaN                 Not Other Cash         NaN
# 9          NaN                              *         NaN
# 10         NaN                              #         NaN
# 11         NaN    Open for I.A.3, # otherwise         NaN
# 12         NaN                           NULL         NaN
# 13         NaN                           NULL         NaN
# 14         NaN  HQLA (except A‐0‐Q for I.A.2)         NaN
# 15         NaN                              Y         NaN  >

# %%
test_rule.dtypes
# Out:
# Unnamed: 0                                              float64
# (1) High‐Quality Liquid Assets (Subpart C, §.20‐.22)     object
# Unnamed: 1                                              float64
# Unnamed: 2                                               object
# Unnamed: 3                                              float64
# dtype: object

# %%
test_rule.info
# Out:
# <bound method DataFrame.info of     Unnamed: 0 (1) High‐Quality Liquid Assets (Subpart C, §.20‐.22)  \
# 0          NaN                                                NaN
# 1          NaN                                              Field
# 2          NaN                                   Reporting Entity
# 3          NaN                                           Currency
# 4          NaN                                          Converted
# 5          NaN                                                PID
# 6          NaN                                            Product
# 7          NaN                                                SID
# 8          NaN                                        Sub‐Product
# 9          NaN                                       Market Value
# 10         NaN                                     Lendable Value
# 11         NaN                                    Maturity Bucket
# 12         NaN                               Forward Start Amount
# 13         NaN                               Forward Start Bucket
# 14         NaN                                   Collateral Class
# 15         NaN                                   Treasury Control
#
#     Unnamed: 1                     Unnamed: 2  Unnamed: 3
# 0          NaN                            NaN         NaN
# 1          NaN                          Value         NaN
# 2          NaN                       LCR Firm         NaN
# 3          NaN                              *         NaN
# 4          NaN                              #         NaN
# 5          NaN                I.A.1, 2, and 3         NaN
# 6          NaN                    Matches PID         NaN
# 7          NaN            Matches Sub‐Product         NaN
# 8          NaN                 Not Other Cash         NaN
# 9          NaN                              *         NaN
# 10         NaN                              #         NaN
# 11         NaN    Open for I.A.3, # otherwise         NaN
# 12         NaN                           NULL         NaN
# 13         NaN                           NULL         NaN
# 14         NaN  HQLA (except A‐0‐Q for I.A.2)         NaN
# 15         NaN                              Y         NaN  >

# %%
test = test_rule.loc[1:16]
test = test.iloc[:,[1,3]]
test
# Out:
#    (1) High‐Quality Liquid Assets (Subpart C, §.20‐.22)  \
# 1                                               Field
# 2                                    Reporting Entity
# 3                                            Currency
# 4                                           Converted
# 5                                                 PID
# 6                                             Product
# 7                                                 SID
# 8                                         Sub‐Product
# 9                                        Market Value
# 10                                     Lendable Value
# 11                                    Maturity Bucket
# 12                               Forward Start Amount
# 13                               Forward Start Bucket
# 14                                   Collateral Class
# 15                                   Treasury Control
#
#                        Unnamed: 2
# 1                           Value
# 2                        LCR Firm
# 3                               *
# 4                               #
# 5                 I.A.1, 2, and 3
# 6                     Matches PID
# 7             Matches Sub‐Product
# 8                  Not Other Cash
# 9                               *
# 10                              #
# 11    Open for I.A.3, # otherwise
# 12                           NULL
# 13                           NULL
# 14  HQLA (except A‐0‐Q for I.A.2)
# 15                              Y

# %% [markdown]
# Test shows us the rows we want to include, obviously the name of our first column needs to be reassigned to the data next

# %%
testx = (test.T.reset_index().T.reset_index(drop=True)
            .set_axis([f'0.{i}' for i in range(test.shape[1])], axis=1))
testx
# Out:
#                                                   0.0  \
# 0   (1) High‐Quality Liquid Assets (Subpart C, §.2...
# 1                                               Field
# 2                                    Reporting Entity
# 3                                            Currency
# 4                                           Converted
# 5                                                 PID
# 6                                             Product
# 7                                                 SID
# 8                                         Sub‐Product
# 9                                        Market Value
# 10                                     Lendable Value
# 11                                    Maturity Bucket
# 12                               Forward Start Amount
# 13                               Forward Start Bucket
# 14                                   Collateral Class
# 15                                   Treasury Control
#
#                               0.1
# 0                      Unnamed: 2
# 1                           Value
# 2                        LCR Firm
# 3                               *
# 4                               #
# 5                 I.A.1, 2, and 3
# 6                     Matches PID
# 7             Matches Sub‐Product
# 8                  Not Other Cash
# 9                               *
# 10                              #
# 11    Open for I.A.3, # otherwise
# 12                           NULL
# 13                           NULL
# 14  HQLA (except A‐0‐Q for I.A.2)
# 15                              Y

# %% [markdown]
# testx has got the format updated moving the column names down to the first row and creating dummy column names, I will next transpose the data frame

# %%
testx = testx.transpose()
testx
# Out:
#                                                      0      1  \
# 0.0  (1) High‐Quality Liquid Assets (Subpart C, §.2...  Field
# 0.1                                         Unnamed: 2  Value
#
#                     2         3          4                5            6  \
# 0.0  Reporting Entity  Currency  Converted              PID      Product
# 0.1          LCR Firm         *          #  I.A.1, 2, and 3  Matches PID
#
#                        7               8             9              10  \
# 0.0                  SID     Sub‐Product  Market Value  Lendable Value
# 0.1  Matches Sub‐Product  Not Other Cash             *               #
#
#                               11                    12                    13  \
# 0.0              Maturity Bucket  Forward Start Amount  Forward Start Bucket
# 0.1  Open for I.A.3, # otherwise                  NULL                  NULL
#
#                                 14                15
# 0.0               Collateral Class  Treasury Control
# 0.1  HQLA (except A‐0‐Q for I.A.2)                 Y

# %% [markdown]
# Transposing the data frame got the format 80% there, we need to move the LCR Rule Name down to the 2nd row, and them move the 1st row to the column names

# %%
i = testx[0.0].iloc[0]
i
# Out:
# '(1) High‐Quality Liquid Assets (Subpart C, §.20‐.22)'

# %%
testR = testx[1].iloc[0]
testR
# Out:
# 'Field'

# %%
testy = testx.replace(testx.iloc[1,0],
                  i,
                     inplace = True)

# %%
testx
# Out:
#                                                      0      1  \
# 0.0  (1) High‐Quality Liquid Assets (Subpart C, §.2...  Field
# 0.1  (1) High‐Quality Liquid Assets (Subpart C, §.2...  Value
#
#                     2         3          4                5            6  \
# 0.0  Reporting Entity  Currency  Converted              PID      Product
# 0.1          LCR Firm         *          #  I.A.1, 2, and 3  Matches PID
#
#                        7               8             9              10  \
# 0.0                  SID     Sub‐Product  Market Value  Lendable Value
# 0.1  Matches Sub‐Product  Not Other Cash             *               #
#
#                               11                    12                    13  \
# 0.0              Maturity Bucket  Forward Start Amount  Forward Start Bucket
# 0.1  Open for I.A.3, # otherwise                  NULL                  NULL
#
#                                 14                15
# 0.0               Collateral Class  Treasury Control
# 0.1  HQLA (except A‐0‐Q for I.A.2)                 Y

# %%
testx.shape
# Out:
# (2, 16)

# %%
testx
# Out:
#                                                      0      1  \
# 0.0  (1) High‐Quality Liquid Assets (Subpart C, §.2...  Field
# 0.1  (1) High‐Quality Liquid Assets (Subpart C, §.2...  Value
#
#                     2         3          4                5            6  \
# 0.0  Reporting Entity  Currency  Converted              PID      Product
# 0.1          LCR Firm         *          #  I.A.1, 2, and 3  Matches PID
#
#                        7               8             9              10  \
# 0.0                  SID     Sub‐Product  Market Value  Lendable Value
# 0.1  Matches Sub‐Product  Not Other Cash             *               #
#
#                               11                    12                    13  \
# 0.0              Maturity Bucket  Forward Start Amount  Forward Start Bucket
# 0.1  Open for I.A.3, # otherwise                  NULL                  NULL
#
#                                 14                15
# 0.0               Collateral Class  Treasury Control
# 0.1  HQLA (except A‐0‐Q for I.A.2)                 Y

# %%
testx.iloc[0,0]
# Out:
# '(1) High‐Quality Liquid Assets (Subpart C, §.20‐.22)'

# %%
testx.iloc[1,0]
# Out:
# '(1) High‐Quality Liquid Assets (Subpart C, §.20‐.22)'

# %%
headers = testx.iloc[0]
headers
#testx  = pd.DataFrame(testx.values[1:], columns=headers)
#testx = textx.rename({"(1) High‐Quality Liquid Assets (Subpart C, §.20‐.22)":"LCR Rule"}, axis=1, inplace = True)
#testx
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-288-833c9288a406> in <module>
# ----> 1 headers = testx.iloc[0]
#       2 headers
#       3 #testx  = pd.DataFrame(testx.values[1:], columns=headers)
#       4 #testx = textx.rename({"(1) High‐Quality Liquid Assets (Subpart C, §.20‐.22)":"LCR Rule"}, axis=1, inplace = True)
#       5 #testx
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1766
#    1767             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1768             return self._getitem_axis(maybe_callable, axis=axis)
#    1769
#    1770     def _is_scalar_access(self, key: Tuple):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    2136
#    2137             # validate the location
# -> 2138             self._validate_integer(key, axis)
#    2139
#    2140             return self._get_loc(key, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_integer(self, key, axis)
#    2061         len_axis = len(self.obj._get_axis(axis))
#    2062         if key >= len_axis or key < -len_axis:
# -> 2063             raise IndexError("single positional indexer is out-of-bounds")
#    2064
#    2065     def _getitem_tuple(self, tup: Tuple):
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# Below is a clean up function to clean up a table with formatting as 15:

# %%
def basicTable(df):
    if df = df.shape[15]=(16,5):
        df = df.iloc[1:,1:]
        df = df.reset_index(drop = True)
        df = df.T.reset_index(drop=True).T
